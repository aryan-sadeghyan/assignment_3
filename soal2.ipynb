# %%
import numpy as np 
import pandas as pd 
from math import log
import random
from treelib import Tree , Node
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## loading the data

# %%
path_to_data =  "~/Downloads/prison_dataset.csv"
data = pd.read_csv(path_to_data)

# %%
data.head()
# Out:
#    Fiscal Year Released  Recidivism Reporting Year Race - Ethnicity  \
# 0                  2010                       2013            White
# 1                  2010                       2013            White
# 2                  2010                       2013            White
# 3                  2010                       2013            White
# 4                  2010                       2013            Black
#
#   Age At Release Convicting Offense Classification Convicting Offense Type  \
# 0            <45                          D Felony                 Violent
# 1            >45                          D Felony                   Other
# 2            <45                          D Felony                   Other
# 3            >45                      Other Felony                    Drug
# 4            <45                          D Felony                    Drug
#
#   Convicting Offense Subtype Main Supervising District Release Type  \
# 0                      Other                       3JD       Parole
# 1                      Other                       3JD       Parole
# 2                      Other                       5JD       Parole
# 3                Trafficking                       3JD       Parole
# 4                Trafficking                       3JD       Parole
#
#   Part of Target Population  Recidivism - Return to Prison numeric
# 0                       Yes                                      1
# 1                       Yes                                      1
# 2                       Yes                                      1
# 3                       Yes                                      1
# 4                       Yes                                      1

# %%
class_name = "Recidivism - Return to Prison numeric"

# %% [markdown]
# ## Entropy and information Gain functions

# %%
def Entropy(x):
    values = np.unique(x)
    proportions = []

    # now we capture the amount of times each value is repeating in each feature 
    # basically the proportion of p   in sum of - p * log p  (the entropy formula)

    
    for element in values:
        proportions = np.append(proportions , np.sum(x == element ))
    
    proportions /= sum(proportions)
 
    return sum([-p * log(p,2) for p in proportions])

# %%
Entropy(data[class_name])
# Out:
# 0.9885815658559858

# %%
def Info_gain(var , labels):
    var = np.array(var)
    labels = np.array(labels)
    values = np.unique(var)
    num_rows = np.size(var)
    H_sum=0
    # calculation of conditional entropy of each of the value that the variable can take
    # we rescue the rows where the variable take that valu and that class column
    for v in values:
        L = np.array([labels[k] for k in np.where(var == v)])
        H_sum += (np.size(L)/num_rows)*Entropy(L)


    return Entropy(labels) - H_sum

# %%
Info_gain(data["Release Type"] , data[class_name])
# Out:
# 0.009453934793683172

# %% [markdown]
# ## stopping criterion function

# %%
def same_data(data , class_name) :
    vars = [item for item in data.columns if item  != class_name]
    if len(vars) == 0:
        return True


    cont = 0
    for var in vars :
        if np.size(np.unique(data[var])) == 1 :
            cont += 1 


    if cont == np.size(data.columns) - 1 :
        return True

    return False

# %%
data_test = data.loc[[1,2] , [c for c in data.columns if c not in ["Age At Release" , "Convicting Offense Classification" , "Main Supervising District"]]]
data_test
# Out:
#    Fiscal Year Released  Recidivism Reporting Year Race - Ethnicity  \
# 1                  2010                       2013            White
# 2                  2010                       2013            White
#
#   Convicting Offense Type Convicting Offense Subtype Release Type  \
# 1                   Other                      Other       Parole
# 2                   Other                      Other       Parole
#
#   Part of Target Population  Recidivism - Return to Prison numeric
# 1                       Yes                                      1
# 2                       Yes                                      1

# %%
print(same_data(data_test, class_name))
# Out:
# True

# %%
class MyNode:
    def __init__(self, value,parent_value):
        self.value = value
        self.parent_value = parent_value

# %%
def Learn_DTree(data, class_name, out_str, _root, id):
    out_str += "iteration : {}\n".format(id)
    out_str += "root: {}\n".format(_root)

    # check if the labels are the same
    if np.size(np.unique(data[class_name])) == 1:
        T = Tree()
        T.create_node(str(data[class_name].values[0]) + "{} = {}".format(_root["name"], _root["value"]), str(id),
                     data= MyNode(value= str(data[class_name].values[0]),parent_value=_root["value"]))
        out_str += "all the classes are the same, leaf = {}\n".format(str(data[class_name].values[0]))
        out_str += "-" * 50 + "\n"
        return T, id + 1, out_str
 
    # check if all the rows are the same
    elif same_data(data, class_name):
        values = np.unique(data[class_name])
        _max = 0
        prediction = np.random.choice(values)
        for element in values:
            num_votes = len(np.where(data[class_name] == element))
            if num_votes > _max:
                _max = num_votes
                prediction = element
    
        T = Tree()
        T.create_node(str(prediction) + "| {}= {}".format(_root["name"], _root["value"]), str(id),
                     data= MyNode(value= str(prediction),parent_value=_root["value"]))
        out_str += "all the rows have the same value: leaf = {}\n".format(str(prediction))
        out_str += "-" * 50 + "\n"
        return T, id + 1, out_str

     # we can add aditional stoping conditions here 
     


    # choose variable with the highest info_gain
    else:
        list_of_vars = data.columns[np.where(data.columns != class_name)].to_list()
        max_gain = -np.infty

        # case when we have only one remaining variable
        if len(list_of_vars) == 1:
            winner = list_of_vars[0]

        else:
            out_str += "Entropy class : {}\n".format(Entropy(data[class_name]))
            random.shuffle(list_of_vars)
            for var in list_of_vars:
                _gain = Info_gain(data[var], data[class_name])
                out_str += "Info_gain of {}= {}\n".format(var, _gain)
                if _gain > max_gain:
                    max_gain = _gain
                    winner = var

        values_winner = np.unique(data[winner])
        out_str += "Best variable: {}\n".format(winner)
        out_str += "-" * 50 + "\n"

        # instantiate the data, call recursively
        T = Tree()
        id_winner = id
        
        if _root["value"] != "":
            T.create_node("({} | {} = {})".format(winner,_root["name"],_root["value"],),str(id_winner),
                         data= MyNode(value= winner,parent_value=_root["value"]))
        else:
             T.create_node(str(winner), str(id_winner),
                          data= MyNode(value= winner,parent_value=_root["value"]))




        
        id += 1
        for val in values_winner:
            data_inst = data[data[winner] == val]
            del data_inst[winner]
            Sub_Tree, id, out_str = Learn_DTree(data_inst, class_name, out_str, {"name": winner, "value": val}, id)
            T.paste(str(id_winner), Sub_Tree)
    
    return T, id, out_str

# %%
# Example: Assuming Learn_DTree is properly implemented
T, id, out_str = Learn_DTree(data, class_name, out_str="", _root={"name": "", "value": ""}, id=0)

# %%
tree_output = T.show(stdout=False)  # Get the tree as a string
print(tree_output)  # Directly print the string
# Out:
# Recidivism Reporting Year
# ├── (Age At Release | Recidivism Reporting Year = 2016)
# │   ├── (Convicting Offense Type | Age At Release = >45)
# │   │   ├── (Main Supervising District | Convicting Offense Type = Other)
# │   │   │   ├── (Convicting Offense Classification | Main Supervising District = 5JD)
# │   │   │   │   ├── (Part of Target Population | Convicting Offense Classification = D Felony)
# │   │   │   │   │   ├── (Release Type | Part of Target Population = Yes)
# │   │   │   │   │   │   ├── (Race - Ethnicity | Release Type = Parole)
# │   │   │   │   │   │   │   ├── 0| Race - Ethnicity= Black
# │   │   │   │   │   │   │   └── 0| Race - Ethnicity= White
# │   │   │   │   │   │   └── 1Release Type = Discharged End of Sentence
# │   │   │   │   │   └── 1Part of Target Population = No
# │   │   │   │   └── (Race - Ethnicity | Convicting Offense Classification = Other Felony)
# │   │   │   │       ├── (Release Type | Race - Ethnicity = White)
# │   │   │   │       │   ├── 0| Release Type= Discharged End of Sentence
# │   │   │   │       │   └── 0| Release Type= Parole
# │   │   │   │       └── 0| Race - Ethnicity= Black
# │   │   │   └── (Part of Target Population | Main Supervising District = 3JD)
# │   │   │       ├── (Convicting Offense Classification | Part of Target Population = No)
# │   │   │       │   ├── (Race - Ethnicity | Convicting Offense Classification = Other Felony)
# │   │   │       │   │   ├── 0| Race - Ethnicity= Black
# │   │   │       │   │   └── 0| Race - Ethnicity= White
# │   │   │       │   └── (Release Type | Convicting Offense Classification = D Felony)
# │   │   │       │       ├── (Race - Ethnicity | Release Type = Discharged End of Sentence)
# │   │   │       │       │   ├── 0| Race - Ethnicity= Black
# │   │   │       │       │   └── 0| Race - Ethnicity= White
# │   │   │       │       └── 1Release Type = Parole
# │   │   │       └── (Race - Ethnicity | Part of Target Population = Yes)
# │   │   │           ├── (Convicting Offense Classification | Race - Ethnicity = White)
# │   │   │           │   ├── (Release Type | Convicting Offense Classification = Other Felony)
# │   │   │           │   │   ├── 0| Release Type= Discharged End of Sentence
# │   │   │           │   │   └── 0| Release Type= Parole
# │   │   │           │   └── 0| Convicting Offense Classification= D Felony
# │   │   │           └── (Release Type | Race - Ethnicity = Black)
# │   │   │               ├── (Convicting Offense Classification | Release Type = Discharged End of Sentence)
# │   │   │               │   ├── 0Convicting Offense Classification = D Felony
# │   │   │               │   └── 0| Convicting Offense Classification= Other Felony
# │   │   │               └── (Convicting Offense Classification | Release Type = Parole)
# │   │   │                   ├── 0| Convicting Offense Classification= D Felony
# │   │   │                   └── 0| Convicting Offense Classification= Other Felony
# │   │   ├── (Race - Ethnicity | Convicting Offense Type = Drug)
# │   │   │   ├── (Convicting Offense Classification | Race - Ethnicity = White)
# │   │   │   │   ├── (Convicting Offense Subtype | Convicting Offense Classification = D Felony)
# │   │   │   │   │   ├── (Release Type | Convicting Offense Subtype = Other)
# │   │   │   │   │   │   ├── (Main Supervising District | Release Type = Parole)
# │   │   │   │   │   │   │   ├── 0| Main Supervising District= 3JD
# │   │   │   │   │   │   │   └── 0| Main Supervising District= 5JD
# │   │   │   │   │   │   └── 1Release Type = Discharged End of Sentence
# │   │   │   │   │   └── 1Convicting Offense Subtype = Trafficking
# │   │   │   │   └── (Release Type | Convicting Offense Classification = Other Felony)
# │   │   │   │       ├── (Convicting Offense Subtype | Release Type = Parole)
# │   │   │   │       │   ├── (Main Supervising District | Convicting Offense Subtype = Other)
# │   │   │   │       │   │   ├── 0| Main Supervising District= 3JD
# │   │   │   │       │   │   └── 1Main Supervising District = 5JD
# │   │   │   │       │   └── (Part of Target Population | Convicting Offense Subtype = Trafficking)
# │   │   │   │       │       ├── (Main Supervising District | Part of Target Population = Yes)
# │   │   │   │       │       │   ├── 0| Main Supervising District= 3JD
# │   │   │   │       │       │   └── 0| Main Supervising District= 5JD
# │   │   │   │       │       └── 1Part of Target Population = No
# │   │   │   │       └── (Part of Target Population | Release Type = Discharged End of Sentence)
# │   │   │   │           ├── (Convicting Offense Subtype | Part of Target Population = No)
# │   │   │   │           │   ├── 0| Convicting Offense Subtype= Other
# │   │   │   │           │   └── 0| Convicting Offense Subtype= Trafficking
# │   │   │   │           └── 0Part of Target Population = Yes
# │   │   │   └── (Main Supervising District | Race - Ethnicity = Black)
# │   │   │       ├── (Convicting Offense Subtype | Main Supervising District = 3JD)
# │   │   │       │   ├── (Convicting Offense Classification | Convicting Offense Subtype = Trafficking)
# │   │   │       │   │   ├── (Release Type | Convicting Offense Classification = Other Felony)
# │   │   │       │   │   │   ├── 0| Release Type= Parole
# │   │   │       │   │   │   └── 1Release Type = Discharged End of Sentence
# │   │   │       │   │   └── 0Convicting Offense Classification = D Felony
# │   │   │       │   └── (Release Type | Convicting Offense Subtype = Other)
# │   │   │       │       ├── (Convicting Offense Classification | Release Type = Parole)
# │   │   │       │       │   ├── 0| Convicting Offense Classification= Other Felony
# │   │   │       │       │   └── 1Convicting Offense Classification = D Felony
# │   │   │       │       └── 1Release Type = Discharged End of Sentence
# │   │   │       └── (Convicting Offense Subtype | Main Supervising District = 5JD)
# │   │   │           ├── (Convicting Offense Classification | Convicting Offense Subtype = Trafficking)
# │   │   │           │   ├── 0| Convicting Offense Classification= Other Felony
# │   │   │           │   └── 1Convicting Offense Classification = D Felony
# │   │   │           └── 0| Convicting Offense Subtype= Other
# │   │   └── (Race - Ethnicity | Convicting Offense Type = Violent)
# │   │       ├── (Main Supervising District | Race - Ethnicity = Black)
# │   │       │   ├── (Convicting Offense Classification | Main Supervising District = 5JD)
# │   │       │   │   ├── (Release Type | Convicting Offense Classification = Other Felony)
# │   │       │   │   │   ├── 0| Release Type= Discharged End of Sentence
# │   │       │   │   │   └── 0| Release Type= Parole
# │   │       │   │   └── 1Convicting Offense Classification = D Felony
# │   │       │   └── (Release Type | Main Supervising District = 3JD)
# │   │       │       ├── (Convicting Offense Classification | Release Type = Parole)
# │   │       │       │   ├── 0| Convicting Offense Classification= D Felony
# │   │       │       │   └── 0| Convicting Offense Classification= Other Felony
# │   │       │       └── (Part of Target Population | Release Type = Discharged End of Sentence)
# │   │       │           ├── (Convicting Offense Classification | Part of Target Population = No)
# │   │       │           │   ├── 0| Convicting Offense Classification= D Felony
# │   │       │           │   └── 0| Convicting Offense Classification= Other Felony
# │   │       │           └── 1Part of Target Population = Yes
# │   │       └── (Part of Target Population | Race - Ethnicity = White)
# │   │           ├── (Convicting Offense Classification | Part of Target Population = No)
# │   │           │   ├── (Main Supervising District | Convicting Offense Classification = Other Felony)
# │   │           │   │   ├── 0| Main Supervising District= 3JD
# │   │           │   │   └── 1Main Supervising District = 5JD
# │   │           │   └── 0| Convicting Offense Classification= D Felony
# │   │           └── (Main Supervising District | Part of Target Population = Yes)
# │   │               ├── (Convicting Offense Classification | Main Supervising District = 3JD)
# │   │               │   ├── (Release Type | Convicting Offense Classification = D Felony)
# │   │               │   │   ├── 0| Release Type= Discharged End of Sentence
# │   │               │   │   └── 0| Release Type= Parole
# │   │               │   └── (Release Type | Convicting Offense Classification = Other Felony)
# │   │               │       ├── 0| Release Type= Discharged End of Sentence
# │   │               │       └── 0| Release Type= Parole
# │   │               └── (Convicting Offense Classification | Main Supervising District = 5JD)
# │   │                   ├── (Release Type | Convicting Offense Classification = D Felony)
# │   │                   │   ├── 0Release Type = Discharged End of Sentence
# │   │                   │   └── 0| Release Type= Parole
# │   │                   └── (Release Type | Convicting Offense Classification = Other Felony)
# │   │                       ├── 0| Release Type= Discharged End of Sentence
# │   │                       └── 0| Release Type= Parole
# │   └── (Main Supervising District | Age At Release = <45)
# │       ├── (Convicting Offense Type | Main Supervising District = 3JD)
# │       │   ├── (Part of Target Population | Convicting Offense Type = Other)
# │       │   │   ├── (Convicting Offense Classification | Part of Target Population = Yes)
# │       │   │   │   ├── (Race - Ethnicity | Convicting Offense Classification = Other Felony)
# │       │   │   │   │   ├── (Release Type | Race - Ethnicity = Black)
# │       │   │   │   │   │   ├── 0| Release Type= Discharged End of Sentence
# │       │   │   │   │   │   └── 0| Release Type= Parole
# │       │   │   │   │   └── (Release Type | Race - Ethnicity = White)
# │       │   │   │   │       ├── 0| Release Type= Discharged End of Sentence
# │       │   │   │   │       └── 0| Release Type= Parole
# │       │   │   │   └── (Release Type | Convicting Offense Classification = D Felony)
# │       │   │   │       ├── (Race - Ethnicity | Release Type = Discharged End of Sentence)
# │       │   │   │       │   ├── 0| Race - Ethnicity= Black
# │       │   │   │       │   └── 0| Race - Ethnicity= White
# │       │   │   │       └── (Race - Ethnicity | Release Type = Parole)
# │       │   │   │           ├── 0| Race - Ethnicity= Black
# │       │   │   │           └── 0| Race - Ethnicity= White
# │       │   │   └── (Release Type | Part of Target Population = No)
# │       │   │       ├── (Convicting Offense Classification | Release Type = Discharged End of Sentence)
# │       │   │       │   ├── (Race - Ethnicity | Convicting Offense Classification = D Felony)
# │       │   │       │   │   ├── 0| Race - Ethnicity= Black
# │       │   │       │   │   └── 0| Race - Ethnicity= White
# │       │   │       │   └── (Race - Ethnicity | Convicting Offense Classification = Other Felony)
# │       │   │       │       ├── 0| Race - Ethnicity= Black
# │       │   │       │       └── 0| Race - Ethnicity= White
# │       │   │       └── 1Release Type = Parole
# │       │   ├── (Release Type | Convicting Offense Type = Drug)
# │       │   │   ├── (Part of Target Population | Release Type = Discharged End of Sentence)
# │       │   │   │   ├── (Convicting Offense Classification | Part of Target Population = No)
# │       │   │   │   │   ├── (Convicting Offense Subtype | Convicting Offense Classification = Other Felony)
# │       │   │   │   │   │   ├── (Race - Ethnicity | Convicting Offense Subtype = Other)
# │       │   │   │   │   │   │   ├── 0| Race - Ethnicity= Black
# │       │   │   │   │   │   │   └── 0| Race - Ethnicity= White
# │       │   │   │   │   │   └── (Race - Ethnicity | Convicting Offense Subtype = Trafficking)
# │       │   │   │   │   │       ├── 0| Race - Ethnicity= Black
# │       │   │   │   │   │       └── 0| Race - Ethnicity= White
# │       │   │   │   │   └── (Race - Ethnicity | Convicting Offense Classification = D Felony)
# │       │   │   │   │       ├── (Convicting Offense Subtype | Race - Ethnicity = White)
# │       │   │   │   │       │   ├── 0| Convicting Offense Subtype= Other
# │       │   │   │   │       │   └── 0| Convicting Offense Subtype= Trafficking
# │       │   │   │   │       └── 1Race - Ethnicity = Black
# │       │   │   │   └── (Convicting Offense Classification | Part of Target Population = Yes)
# │       │   │   │       ├── (Convicting Offense Subtype | Convicting Offense Classification = D Felony)
# │       │   │   │       │   ├── 0| Convicting Offense Subtype= Other
# │       │   │   │       │   └── 0| Convicting Offense Subtype= Trafficking
# │       │   │   │       └── (Race - Ethnicity | Convicting Offense Classification = Other Felony)
# │       │   │   │           ├── 0| Race - Ethnicity= Black
# │       │   │   │           └── 0| Race - Ethnicity= White
# │       │   │   └── (Part of Target Population | Release Type = Parole)
# │       │   │       ├── (Convicting Offense Classification | Part of Target Population = Yes)
# │       │   │       │   ├── (Convicting Offense Subtype | Convicting Offense Classification = D Felony)
# │       │   │       │   │   ├── (Race - Ethnicity | Convicting Offense Subtype = Other)
# │       │   │       │   │   │   ├── 0| Race - Ethnicity= Black
# │       │   │       │   │   │   └── 0| Race - Ethnicity= White
# │       │   │       │   │   └── (Race - Ethnicity | Convicting Offense Subtype = Trafficking)
# │       │   │       │   │       ├── 0| Race - Ethnicity= Black
# │       │   │       │   │       └── 0| Race - Ethnicity= White
# │       │   │       │   └── (Race - Ethnicity | Convicting Offense Classification = Other Felony)
# │       │   │       │       ├── (Convicting Offense Subtype | Race - Ethnicity = Black)
# │       │   │       │       │   ├── 0| Convicting Offense Subtype= Other
# │       │   │       │       │   └── 0| Convicting Offense Subtype= Trafficking
# │       │   │       │       └── (Convicting Offense Subtype | Race - Ethnicity = White)
# │       │   │       │           ├── 0| Convicting Offense Subtype= Other
# │       │   │       │           └── 0| Convicting Offense Subtype= Trafficking
# │       │   │       └── 1Part of Target Population = No
# │       │   └── (Release Type | Convicting Offense Type = Violent)
# │       │       ├── (Convicting Offense Classification | Release Type = Discharged End of Sentence)
# │       │       │   ├── (Race - Ethnicity | Convicting Offense Classification = D Felony)
# │       │       │   │   ├── (Part of Target Population | Race - Ethnicity = White)
# │       │       │   │   │   ├── 0| Part of Target Population= No
# │       │       │   │   │   └── 0| Part of Target Population= Yes
# │       │       │   │   └── 0| Race - Ethnicity= Black
# │       │       │   └── (Race - Ethnicity | Convicting Offense Classification = Other Felony)
# │       │       │       ├── (Part of Target Population | Race - Ethnicity = Black)
# │       │       │       │   ├── 0| Part of Target Population= No
# │       │       │       │   └── 0| Part of Target Population= Yes
# │       │       │       └── (Part of Target Population | Race - Ethnicity = White)
# │       │       │           ├── 0| Part of Target Population= No
# │       │       │           └── 0| Part of Target Population= Yes
# │       │       └── (Convicting Offense Classification | Release Type = Parole)
# │       │           ├── (Part of Target Population | Convicting Offense Classification = Other Felony)
# │       │           │   ├── (Race - Ethnicity | Part of Target Population = Yes)
# │       │           │   │   ├── 0| Race - Ethnicity= Black
# │       │           │   │   └── 0| Race - Ethnicity= White
# │       │           │   └── 1Part of Target Population = No
# │       │           └── (Race - Ethnicity | Convicting Offense Classification = D Felony)
# │       │               ├── 0| Race - Ethnicity= Black
# │       │               └── 0| Race - Ethnicity= White
# │       └── (Part of Target Population | Main Supervising District = 5JD)
# │           ├── (Convicting Offense Type | Part of Target Population = Yes)
# │           │   ├── (Race - Ethnicity | Convicting Offense Type = Other)
# │           │   │   ├── (Convicting Offense Classification | Race - Ethnicity = Black)
# │           │   │   │   ├── (Release Type | Convicting Offense Classification = D Felony)
# │           │   │   │   │   ├── 0| Release Type= Parole
# │           │   │   │   │   └── 1Release Type = Discharged End of Sentence
# │           │   │   │   └── (Release Type | Convicting Offense Classification = Other Felony)
# │           │   │   │       ├── 0| Release Type= Discharged End of Sentence
# │           │   │   │       └── 0| Release Type= Parole
# │           │   │   └── (Convicting Offense Classification | Race - Ethnicity = White)
# │           │   │       ├── (Release Type | Convicting Offense Classification = D Felony)
# │           │   │       │   ├── 0| Release Type= Discharged End of Sentence
# │           │   │       │   └── 0| Release Type= Parole
# │           │   │       └── (Release Type | Convicting Offense Classification = Other Felony)
# │           │   │           ├── 0| Release Type= Discharged End of Sentence
# │           │   │           └── 0| Release Type= Parole
# │           │   ├── (Release Type | Convicting Offense Type = Drug)
# │           │   │   ├── (Race - Ethnicity | Release Type = Discharged End of Sentence)
# │           │   │   │   ├── (Convicting Offense Classification | Race - Ethnicity = White)
# │           │   │   │   │   ├── 0| Convicting Offense Classification= Other Felony
# │           │   │   │   │   └── 1Convicting Offense Classification = D Felony
# │           │   │   │   └── 1Race - Ethnicity = Black
# │           │   │   └── (Race - Ethnicity | Release Type = Parole)
# │           │   │       ├── (Convicting Offense Classification | Race - Ethnicity = Black)
# │           │   │       │   ├── (Convicting Offense Subtype | Convicting Offense Classification = D Felony)
# │           │   │       │   │   ├── 0| Convicting Offense Subtype= Other
# │           │   │       │   │   └── 0| Convicting Offense Subtype= Trafficking
# │           │   │       │   └── (Convicting Offense Subtype | Convicting Offense Classification = Other Felony)
# │           │   │       │       ├── 0| Convicting Offense Subtype= Trafficking
# │           │   │       │       └── 1Convicting Offense Subtype = Other
# │           │   │       └── (Convicting Offense Classification | Race - Ethnicity = White)
# │           │   │           ├── (Convicting Offense Subtype | Convicting Offense Classification = D Felony)
# │           │   │           │   ├── 0| Convicting Offense Subtype= Other
# │           │   │           │   └── 0| Convicting Offense Subtype= Trafficking
# │           │   │           └── (Convicting Offense Subtype | Convicting Offense Classification = Other Felony)
# │           │   │               ├── 0| Convicting Offense Subtype= Other
# │           │   │               └── 0| Convicting Offense Subtype= Trafficking
# │           │   └── (Release Type | Convicting Offense Type = Violent)
# │           │       ├── (Convicting Offense Classification | Release Type = Discharged End of Sentence)
# │           │       │   ├── (Race - Ethnicity | Convicting Offense Classification = D Felony)
# │           │       │   │   ├── 0| Race - Ethnicity= White
# │           │       │   │   └── 1Race - Ethnicity = Black
# │           │       │   └── (Race - Ethnicity | Convicting Offense Classification = Other Felony)
# │           │       │       ├── 0| Race - Ethnicity= Black
# │           │       │       └── 0| Race - Ethnicity= White
# │           │       └── (Convicting Offense Classification | Release Type = Parole)
# │           │           ├── (Race - Ethnicity | Convicting Offense Classification = D Felony)
# │           │           │   ├── 0| Race - Ethnicity= Black
# │           │           │   └── 0| Race - Ethnicity= White
# │           │           └── (Race - Ethnicity | Convicting Offense Classification = Other Felony)
# │           │               ├── 0| Race - Ethnicity= Black
# │           │               └── 0| Race - Ethnicity= White
# │           └── 1Part of Target Population = No
# ├── (Release Type | Recidivism Reporting Year = 2018)
# │   ├── (Age At Release | Release Type = Parole)
# │   │   ├── (Convicting Offense Type | Age At Release = <45)
# │   │   │   ├── (Convicting Offense Classification | Convicting Offense Type = Drug)
# │   │   │   │   ├── (Part of Target Population | Convicting Offense Classification = D Felony)
# │   │   │   │   │   ├── (Convicting Offense Subtype | Part of Target Population = No)
# │   │   │   │   │   │   ├── (Main Supervising District | Convicting Offense Subtype = Trafficking)
# │   │   │   │   │   │   │   ├── (Race - Ethnicity | Main Supervising District = 3JD)
# │   │   │   │   │   │   │   │   ├── 0| Race - Ethnicity= Black
# │   │   │   │   │   │   │   │   └── 0| Race - Ethnicity= White
# │   │   │   │   │   │   │   └── (Race - Ethnicity | Main Supervising District = 5JD)
# │   │   │   │   │   │   │       ├── 0| Race - Ethnicity= Black
# │   │   │   │   │   │   │       └── 0| Race - Ethnicity= White
# │   │   │   │   │   │   └── (Race - Ethnicity | Convicting Offense Subtype = Other)
# │   │   │   │   │   │       ├── (Main Supervising District | Race - Ethnicity = Black)
# │   │   │   │   │   │       │   ├── 0| Main Supervising District= 3JD
# │   │   │   │   │   │       │   └── 0| Main Supervising District= 5JD
# │   │   │   │   │   │       └── (Main Supervising District | Race - Ethnicity = White)
# │   │   │   │   │   │           ├── 0| Main Supervising District= 3JD
# │   │   │   │   │   │           └── 0| Main Supervising District= 5JD
# │   │   │   │   │   └── (Main Supervising District | Part of Target Population = Yes)
# │   │   │   │   │       ├── (Convicting Offense Subtype | Main Supervising District = 5JD)
# │   │   │   │   │       │   ├── (Race - Ethnicity | Convicting Offense Subtype = Other)
# │   │   │   │   │       │   │   ├── 0| Race - Ethnicity= Black
# │   │   │   │   │       │   │   └── 0| Race - Ethnicity= White
# │   │   │   │   │       │   └── (Race - Ethnicity | Convicting Offense Subtype = Trafficking)
# │   │   │   │   │       │       ├── 0| Race - Ethnicity= Black
# │   │   │   │   │       │       └── 0| Race - Ethnicity= White
# │   │   │   │   │       └── (Race - Ethnicity | Main Supervising District = 3JD)
# │   │   │   │   │           ├── (Convicting Offense Subtype | Race - Ethnicity = Black)
# │   │   │   │   │           │   ├── 0| Convicting Offense Subtype= Other
# │   │   │   │   │           │   └── 0| Convicting Offense Subtype= Trafficking
# │   │   │   │   │           └── (Convicting Offense Subtype | Race - Ethnicity = White)
# │   │   │   │   │               ├── 0| Convicting Offense Subtype= Other
# │   │   │   │   │               └── 0| Convicting Offense Subtype= Trafficking
# │   │   │   │   └── (Race - Ethnicity | Convicting Offense Classification = Other Felony)
# │   │   │   │       ├── (Convicting Offense Subtype | Race - Ethnicity = Black)
# │   │   │   │       │   ├── (Main Supervising District | Convicting Offense Subtype = Other)
# │   │   │   │       │   │   ├── 0Main Supervising District = 5JD
# │   │   │   │       │   │   └── 0| Main Supervising District= 3JD
# │   │   │   │       │   └── (Main Supervising District | Convicting Offense Subtype = Trafficking)
# │   │   │   │       │       ├── (Part of Target Population | Main Supervising District = 3JD)
# │   │   │   │       │       │   ├── 0| Part of Target Population= No
# │   │   │   │       │       │   └── 0| Part of Target Population= Yes
# │   │   │   │       │       └── (Part of Target Population | Main Supervising District = 5JD)
# │   │   │   │       │           ├── 0| Part of Target Population= No
# │   │   │   │       │           └── 0| Part of Target Population= Yes
# │   │   │   │       └── (Part of Target Population | Race - Ethnicity = White)
# │   │   │   │           ├── (Convicting Offense Subtype | Part of Target Population = No)
# │   │   │   │           │   ├── (Main Supervising District | Convicting Offense Subtype = Other)
# │   │   │   │           │   │   ├── 0| Main Supervising District= 3JD
# │   │   │   │           │   │   └── 0| Main Supervising District= 5JD
# │   │   │   │           │   └── (Main Supervising District | Convicting Offense Subtype = Trafficking)
# │   │   │   │           │       ├── 0| Main Supervising District= 3JD
# │   │   │   │           │       └── 0| Main Supervising District= 5JD
# │   │   │   │           └── (Convicting Offense Subtype | Part of Target Population = Yes)
# │   │   │   │               ├── (Main Supervising District | Convicting Offense Subtype = Other)
# │   │   │   │               │   ├── 0| Main Supervising District= 3JD
# │   │   │   │               │   └── 0| Main Supervising District= 5JD
# │   │   │   │               └── (Main Supervising District | Convicting Offense Subtype = Trafficking)
# │   │   │   │                   ├── 0| Main Supervising District= 3JD
# │   │   │   │                   └── 0| Main Supervising District= 5JD
# │   │   │   ├── (Main Supervising District | Convicting Offense Type = Other)
# │   │   │   │   ├── (Part of Target Population | Main Supervising District = 3JD)
# │   │   │   │   │   ├── (Race - Ethnicity | Part of Target Population = No)
# │   │   │   │   │   │   ├── (Convicting Offense Classification | Race - Ethnicity = Black)
# │   │   │   │   │   │   │   ├── 0| Convicting Offense Classification= D Felony
# │   │   │   │   │   │   │   └── 0| Convicting Offense Classification= Other Felony
# │   │   │   │   │   │   └── (Convicting Offense Classification | Race - Ethnicity = White)
# │   │   │   │   │   │       ├── 0| Convicting Offense Classification= D Felony
# │   │   │   │   │   │       └── 0| Convicting Offense Classification= Other Felony
# │   │   │   │   │   └── (Race - Ethnicity | Part of Target Population = Yes)
# │   │   │   │   │       ├── (Convicting Offense Classification | Race - Ethnicity = Black)
# │   │   │   │   │       │   ├── 0| Convicting Offense Classification= D Felony
# │   │   │   │   │       │   └── 0| Convicting Offense Classification= Other Felony
# │   │   │   │   │       └── (Convicting Offense Classification | Race - Ethnicity = White)
# │   │   │   │   │           ├── 0| Convicting Offense Classification= D Felony
# │   │   │   │   │           └── 0| Convicting Offense Classification= Other Felony
# │   │   │   │   └── (Part of Target Population | Main Supervising District = 5JD)
# │   │   │   │       ├── (Convicting Offense Classification | Part of Target Population = Yes)
# │   │   │   │       │   ├── (Race - Ethnicity | Convicting Offense Classification = D Felony)
# │   │   │   │       │   │   ├── 0| Race - Ethnicity= Black
# │   │   │   │       │   │   └── 0| Race - Ethnicity= White
# │   │   │   │       │   └── (Race - Ethnicity | Convicting Offense Classification = Other Felony)
# │   │   │   │       │       ├── 0| Race - Ethnicity= Black
# │   │   │   │       │       └── 0| Race - Ethnicity= White
# │   │   │   │       └── (Race - Ethnicity | Part of Target Population = No)
# │   │   │   │           ├── (Convicting Offense Classification | Race - Ethnicity = Black)
# │   │   │   │           │   ├── 0| Convicting Offense Classification= D Felony
# │   │   │   │           │   └── 0| Convicting Offense Classification= Other Felony
# │   │   │   │           └── (Convicting Offense Classification | Race - Ethnicity = White)
# │   │   │   │               ├── 0| Convicting Offense Classification= D Felony
# │   │   │   │               └── 0| Convicting Offense Classification= Other Felony
# │   │   │   └── (Race - Ethnicity | Convicting Offense Type = Violent)
# │   │   │       ├── (Main Supervising District | Race - Ethnicity = Black)
# │   │   │       │   ├── (Part of Target Population | Main Supervising District = 3JD)
# │   │   │       │   │   ├── (Convicting Offense Classification | Part of Target Population = No)
# │   │   │       │   │   │   ├── 0| Convicting Offense Classification= D Felony
# │   │   │       │   │   │   └── 0| Convicting Offense Classification= Other Felony
# │   │   │       │   │   └── (Convicting Offense Classification | Part of Target Population = Yes)
# │   │   │       │   │       ├── 0| Convicting Offense Classification= D Felony
# │   │   │       │   │       └── 0| Convicting Offense Classification= Other Felony
# │   │   │       │   └── (Part of Target Population | Main Supervising District = 5JD)
# │   │   │       │       ├── (Convicting Offense Classification | Part of Target Population = No)
# │   │   │       │       │   ├── 0| Convicting Offense Classification= D Felony
# │   │   │       │       │   └── 0| Convicting Offense Classification= Other Felony
# │   │   │       │       └── (Fiscal Year Released | Part of Target Population = Yes)
# │   │   │       │           └── (Convicting Offense Subtype | Fiscal Year Released = 2015)
# │   │   │       │               └── (Convicting Offense Classification | Convicting Offense Subtype = Other)
# │   │   │       │                   ├── 0| Convicting Offense Classification= D Felony
# │   │   │       │                   └── 0| Convicting Offense Classification= Other Felony
# │   │   │       └── (Part of Target Population | Race - Ethnicity = White)
# │   │   │           ├── (Convicting Offense Classification | Part of Target Population = No)
# │   │   │           │   ├── (Main Supervising District | Convicting Offense Classification = D Felony)
# │   │   │           │   │   ├── 0| Main Supervising District= 3JD
# │   │   │           │   │   └── 0| Main Supervising District= 5JD
# │   │   │           │   └── (Main Supervising District | Convicting Offense Classification = Other Felony)
# │   │   │           │       ├── 0| Main Supervising District= 3JD
# │   │   │           │       └── 0| Main Supervising District= 5JD
# │   │   │           └── (Main Supervising District | Part of Target Population = Yes)
# │   │   │               ├── (Convicting Offense Classification | Main Supervising District = 3JD)
# │   │   │               │   ├── 0| Convicting Offense Classification= D Felony
# │   │   │               │   └── 0| Convicting Offense Classification= Other Felony
# │   │   │               └── (Convicting Offense Classification | Main Supervising District = 5JD)
# │   │   │                   ├── 0| Convicting Offense Classification= D Felony
# │   │   │                   └── 0| Convicting Offense Classification= Other Felony
# │   │   └── (Part of Target Population | Age At Release = >45)
# │   │       ├── (Convicting Offense Type | Part of Target Population = No)
# │   │       │   ├── (Convicting Offense Subtype | Convicting Offense Type = Drug)
# │   │       │   │   ├── (Convicting Offense Classification | Convicting Offense Subtype = Trafficking)
# │   │       │   │   │   ├── (Main Supervising District | Convicting Offense Classification = Other Felony)
# │   │       │   │   │   │   ├── (Race - Ethnicity | Main Supervising District = 3JD)
# │   │       │   │   │   │   │   ├── 0| Race - Ethnicity= Black
# │   │       │   │   │   │   │   └── 0| Race - Ethnicity= White
# │   │       │   │   │   │   └── (Race - Ethnicity | Main Supervising District = 5JD)
# │   │       │   │   │   │       ├── 0| Race - Ethnicity= Black
# │   │       │   │   │   │       └── 0| Race - Ethnicity= White
# │   │       │   │   │   └── (Race - Ethnicity | Convicting Offense Classification = D Felony)
# │   │       │   │   │       ├── (Main Supervising District | Race - Ethnicity = White)
# │   │       │   │   │       │   ├── 0Main Supervising District = 5JD
# │   │       │   │   │       │   └── 0| Main Supervising District= 3JD
# │   │       │   │   │       └── 0| Race - Ethnicity= Black
# │   │       │   │   └── (Race - Ethnicity | Convicting Offense Subtype = Other)
# │   │       │   │       ├── (Convicting Offense Classification | Race - Ethnicity = Black)
# │   │       │   │       │   ├── (Main Supervising District | Convicting Offense Classification = D Felony)
# │   │       │   │       │   │   ├── 0| Main Supervising District= 3JD
# │   │       │   │       │   │   └── 0| Main Supervising District= 5JD
# │   │       │   │       │   └── 1Convicting Offense Classification = Other Felony
# │   │       │   │       └── (Main Supervising District | Race - Ethnicity = White)
# │   │       │   │           ├── (Convicting Offense Classification | Main Supervising District = 3JD)
# │   │       │   │           │   ├── 0Convicting Offense Classification = Other Felony
# │   │       │   │           │   └── 0| Convicting Offense Classification= D Felony
# │   │       │   │           └── (Convicting Offense Classification | Main Supervising District = 5JD)
# │   │       │   │               ├── 0| Convicting Offense Classification= D Felony
# │   │       │   │               └── 0| Convicting Offense Classification= Other Felony
# │   │       │   ├── (Main Supervising District | Convicting Offense Type = Violent)
# │   │       │   │   ├── (Convicting Offense Classification | Main Supervising District = 5JD)
# │   │       │   │   │   ├── (Race - Ethnicity | Convicting Offense Classification = D Felony)
# │   │       │   │   │   │   ├── 0Race - Ethnicity = Black
# │   │       │   │   │   │   └── 0| Race - Ethnicity= White
# │   │       │   │   │   └── (Race - Ethnicity | Convicting Offense Classification = Other Felony)
# │   │       │   │   │       ├── 0| Race - Ethnicity= Black
# │   │       │   │   │       └── 0| Race - Ethnicity= White
# │   │       │   │   └── (Race - Ethnicity | Main Supervising District = 3JD)
# │   │       │   │       ├── (Convicting Offense Classification | Race - Ethnicity = Black)
# │   │       │   │       │   ├── 0| Convicting Offense Classification= D Felony
# │   │       │   │       │   └── 0| Convicting Offense Classification= Other Felony
# │   │       │   │       └── (Convicting Offense Classification | Race - Ethnicity = White)
# │   │       │   │           ├── 0| Convicting Offense Classification= D Felony
# │   │       │   │           └── 0| Convicting Offense Classification= Other Felony
# │   │       │   └── (Race - Ethnicity | Convicting Offense Type = Other)
# │   │       │       ├── (Main Supervising District | Race - Ethnicity = Black)
# │   │       │       │   ├── (Convicting Offense Classification | Main Supervising District = 3JD)
# │   │       │       │   │   ├── 0| Convicting Offense Classification= D Felony
# │   │       │       │   │   └── 0| Convicting Offense Classification= Other Felony
# │   │       │       │   └── (Convicting Offense Classification | Main Supervising District = 5JD)
# │   │       │       │       ├── 0| Convicting Offense Classification= D Felony
# │   │       │       │       └── 0| Convicting Offense Classification= Other Felony
# │   │       │       └── (Main Supervising District | Race - Ethnicity = White)
# │   │       │           ├── (Convicting Offense Classification | Main Supervising District = 3JD)
# │   │       │           │   ├── 0| Convicting Offense Classification= D Felony
# │   │       │           │   └── 0| Convicting Offense Classification= Other Felony
# │   │       │           └── (Convicting Offense Classification | Main Supervising District = 5JD)
# │   │       │               ├── 0| Convicting Offense Classification= D Felony
# │   │       │               └── 0| Convicting Offense Classification= Other Felony
# │   │       └── (Main Supervising District | Part of Target Population = Yes)
# │   │           ├── (Convicting Offense Classification | Main Supervising District = 3JD)
# │   │           │   ├── (Convicting Offense Type | Convicting Offense Classification = Other Felony)
# │   │           │   │   ├── (Convicting Offense Subtype | Convicting Offense Type = Drug)
# │   │           │   │   │   ├── (Race - Ethnicity | Convicting Offense Subtype = Trafficking)
# │   │           │   │   │   │   ├── 0| Race - Ethnicity= Black
# │   │           │   │   │   │   └── 0| Race - Ethnicity= White
# │   │           │   │   │   └── 0Convicting Offense Subtype = Other
# │   │           │   │   ├── (Race - Ethnicity | Convicting Offense Type = Other)
# │   │           │   │   │   ├── 0| Race - Ethnicity= Black
# │   │           │   │   │   └── 0| Race - Ethnicity= White
# │   │           │   │   └── (Race - Ethnicity | Convicting Offense Type = Violent)
# │   │           │   │       ├── 0| Race - Ethnicity= Black
# │   │           │   │       └── 0| Race - Ethnicity= White
# │   │           │   └── (Race - Ethnicity | Convicting Offense Classification = D Felony)
# │   │           │       ├── (Convicting Offense Subtype | Race - Ethnicity = Black)
# │   │           │       │   ├── (Convicting Offense Type | Convicting Offense Subtype = Other)
# │   │           │       │   │   ├── 0| Convicting Offense Type= Drug
# │   │           │       │   │   ├── 0| Convicting Offense Type= Other
# │   │           │       │   │   └── 0| Convicting Offense Type= Violent
# │   │           │       │   └── 0| Convicting Offense Subtype= Trafficking
# │   │           │       └── (Convicting Offense Subtype | Race - Ethnicity = White)
# │   │           │           ├── (Convicting Offense Type | Convicting Offense Subtype = Other)
# │   │           │           │   ├── 0| Convicting Offense Type= Drug
# │   │           │           │   ├── 0| Convicting Offense Type= Other
# │   │           │           │   └── 0| Convicting Offense Type= Violent
# │   │           │           └── 0Convicting Offense Subtype = Trafficking
# │   │           └── (Convicting Offense Type | Main Supervising District = 5JD)
# │   │               ├── (Convicting Offense Classification | Convicting Offense Type = Violent)
# │   │               │   ├── (Race - Ethnicity | Convicting Offense Classification = D Felony)
# │   │               │   │   ├── 0| Race - Ethnicity= Black
# │   │               │   │   └── 0| Race - Ethnicity= White
# │   │               │   └── (Race - Ethnicity | Convicting Offense Classification = Other Felony)
# │   │               │       ├── 0| Race - Ethnicity= Black
# │   │               │       └── 0| Race - Ethnicity= White
# │   │               ├── (Convicting Offense Subtype | Convicting Offense Type = Drug)
# │   │               │   ├── (Convicting Offense Classification | Convicting Offense Subtype = Trafficking)
# │   │               │   │   ├── (Race - Ethnicity | Convicting Offense Classification = D Felony)
# │   │               │   │   │   ├── 0Race - Ethnicity = Black
# │   │               │   │   │   └── 0| Race - Ethnicity= White
# │   │               │   │   └── (Race - Ethnicity | Convicting Offense Classification = Other Felony)
# │   │               │   │       ├── 0| Race - Ethnicity= Black
# │   │               │   │       └── 0| Race - Ethnicity= White
# │   │               │   └── (Race - Ethnicity | Convicting Offense Subtype = Other)
# │   │               │       ├── (Convicting Offense Classification | Race - Ethnicity = White)
# │   │               │       │   ├── 0| Convicting Offense Classification= D Felony
# │   │               │       │   └── 0| Convicting Offense Classification= Other Felony
# │   │               │       └── 1Race - Ethnicity = Black
# │   │               └── (Race - Ethnicity | Convicting Offense Type = Other)
# │   │                   ├── (Convicting Offense Classification | Race - Ethnicity = Black)
# │   │                   │   ├── 0| Convicting Offense Classification= D Felony
# │   │                   │   └── 0| Convicting Offense Classification= Other Felony
# │   │                   └── (Convicting Offense Classification | Race - Ethnicity = White)
# │   │                       ├── 0| Convicting Offense Classification= D Felony
# │   │                       └── 0| Convicting Offense Classification= Other Felony
# │   └── (Main Supervising District | Release Type = Discharged End of Sentence)
# │       ├── (Age At Release | Main Supervising District = 3JD)
# │       │   ├── (Convicting Offense Type | Age At Release = <45)
# │       │   │   ├── (Convicting Offense Classification | Convicting Offense Type = Other)
# │       │   │   │   ├── (Part of Target Population | Convicting Offense Classification = Other Felony)
# │       │   │   │   │   ├── (Race - Ethnicity | Part of Target Population = No)
# │       │   │   │   │   │   ├── 0| Race - Ethnicity= Black
# │       │   │   │   │   │   └── 0| Race - Ethnicity= White
# │       │   │   │   │   └── (Race - Ethnicity | Part of Target Population = Yes)
# │       │   │   │   │       ├── 0| Race - Ethnicity= Black
# │       │   │   │   │       └── 0| Race - Ethnicity= White
# │       │   │   │   └── (Race - Ethnicity | Convicting Offense Classification = D Felony)
# │       │   │   │       ├── (Part of Target Population | Race - Ethnicity = Black)
# │       │   │   │       │   ├── 0| Part of Target Population= No
# │       │   │   │       │   └── 0| Part of Target Population= Yes
# │       │   │   │       └── (Part of Target Population | Race - Ethnicity = White)
# │       │   │   │           ├── 0| Part of Target Population= No
# │       │   │   │           └── 0| Part of Target Population= Yes
# │       │   │   ├── (Part of Target Population | Convicting Offense Type = Drug)
# │       │   │   │   ├── (Convicting Offense Subtype | Part of Target Population = No)
# │       │   │   │   │   ├── (Convicting Offense Classification | Convicting Offense Subtype = Other)
# │       │   │   │   │   │   ├── (Race - Ethnicity | Convicting Offense Classification = D Felony)
# │       │   │   │   │   │   │   ├── 0Race - Ethnicity = Black
# │       │   │   │   │   │   │   └── 0| Race - Ethnicity= White
# │       │   │   │   │   │   └── (Race - Ethnicity | Convicting Offense Classification = Other Felony)
# │       │   │   │   │   │       ├── 0| Race - Ethnicity= Black
# │       │   │   │   │   │       └── 0| Race - Ethnicity= White
# │       │   │   │   │   └── (Convicting Offense Classification | Convicting Offense Subtype = Trafficking)
# │       │   │   │   │       ├── (Race - Ethnicity | Convicting Offense Classification = D Felony)
# │       │   │   │   │       │   ├── 0| Race - Ethnicity= Black
# │       │   │   │   │       │   └── 0| Race - Ethnicity= White
# │       │   │   │   │       └── (Race - Ethnicity | Convicting Offense Classification = Other Felony)
# │       │   │   │   │           ├── 0| Race - Ethnicity= Black
# │       │   │   │   │           └── 0| Race - Ethnicity= White
# │       │   │   │   └── (Convicting Offense Subtype | Part of Target Population = Yes)
# │       │   │   │       ├── (Race - Ethnicity | Convicting Offense Subtype = Other)
# │       │   │   │       │   ├── (Convicting Offense Classification | Race - Ethnicity = Black)
# │       │   │   │       │   │   ├── 0| Convicting Offense Classification= D Felony
# │       │   │   │       │   │   └── 0| Convicting Offense Classification= Other Felony
# │       │   │   │       │   └── (Convicting Offense Classification | Race - Ethnicity = White)
# │       │   │   │       │       ├── 0| Convicting Offense Classification= D Felony
# │       │   │   │       │       └── 0| Convicting Offense Classification= Other Felony
# │       │   │   │       └── (Race - Ethnicity | Convicting Offense Subtype = Trafficking)
# │       │   │   │           ├── (Convicting Offense Classification | Race - Ethnicity = Black)
# │       │   │   │           │   ├── 0| Convicting Offense Classification= D Felony
# │       │   │   │           │   └── 0| Convicting Offense Classification= Other Felony
# │       │   │   │           └── (Convicting Offense Classification | Race - Ethnicity = White)
# │       │   │   │               ├── 0| Convicting Offense Classification= D Felony
# │       │   │   │               └── 0| Convicting Offense Classification= Other Felony
# │       │   │   └── (Part of Target Population | Convicting Offense Type = Violent)
# │       │   │       ├── (Convicting Offense Classification | Part of Target Population = Yes)
# │       │   │       │   ├── (Race - Ethnicity | Convicting Offense Classification = D Felony)
# │       │   │       │   │   ├── 0| Race - Ethnicity= Black
# │       │   │       │   │   └── 0| Race - Ethnicity= White
# │       │   │       │   └── (Race - Ethnicity | Convicting Offense Classification = Other Felony)
# │       │   │       │       ├── 0| Race - Ethnicity= Black
# │       │   │       │       └── 0| Race - Ethnicity= White
# │       │   │       └── (Race - Ethnicity | Part of Target Population = No)
# │       │   │           ├── (Convicting Offense Classification | Race - Ethnicity = Black)
# │       │   │           │   ├── 0| Convicting Offense Classification= D Felony
# │       │   │           │   └── 0| Convicting Offense Classification= Other Felony
# │       │   │           └── (Convicting Offense Classification | Race - Ethnicity = White)
# │       │   │               ├── 0| Convicting Offense Classification= D Felony
# │       │   │               └── 0| Convicting Offense Classification= Other Felony
# │       │   └── (Convicting Offense Type | Age At Release = >45)
# │       │       ├── (Convicting Offense Classification | Convicting Offense Type = Drug)
# │       │       │   ├── (Convicting Offense Subtype | Convicting Offense Classification = Other Felony)
# │       │       │   │   ├── (Part of Target Population | Convicting Offense Subtype = Trafficking)
# │       │       │   │   │   ├── (Race - Ethnicity | Part of Target Population = No)
# │       │       │   │   │   │   ├── 0Race - Ethnicity = Black
# │       │       │   │   │   │   └── 0| Race - Ethnicity= White
# │       │       │   │   │   └── (Race - Ethnicity | Part of Target Population = Yes)
# │       │       │   │   │       ├── 0Race - Ethnicity = White
# │       │       │   │   │       └── 0| Race - Ethnicity= Black
# │       │       │   │   └── 0Convicting Offense Subtype = Other
# │       │       │   └── (Part of Target Population | Convicting Offense Classification = D Felony)
# │       │       │       ├── (Convicting Offense Subtype | Part of Target Population = No)
# │       │       │       │   ├── 0Convicting Offense Subtype = Trafficking
# │       │       │       │   └── 0| Convicting Offense Subtype= Other
# │       │       │       └── 0Part of Target Population = Yes
# │       │       ├── (Convicting Offense Classification | Convicting Offense Type = Other)
# │       │       │   ├── (Part of Target Population | Convicting Offense Classification = D Felony)
# │       │       │   │   ├── (Race - Ethnicity | Part of Target Population = No)
# │       │       │   │   │   ├── 0| Race - Ethnicity= Black
# │       │       │   │   │   └── 0| Race - Ethnicity= White
# │       │       │   │   └── (Race - Ethnicity | Part of Target Population = Yes)
# │       │       │   │       ├── 0| Race - Ethnicity= Black
# │       │       │   │       └── 0| Race - Ethnicity= White
# │       │       │   └── (Part of Target Population | Convicting Offense Classification = Other Felony)
# │       │       │       ├── (Race - Ethnicity | Part of Target Population = No)
# │       │       │       │   ├── 0| Race - Ethnicity= Black
# │       │       │       │   └── 0| Race - Ethnicity= White
# │       │       │       └── (Race - Ethnicity | Part of Target Population = Yes)
# │       │       │           ├── 0| Race - Ethnicity= Black
# │       │       │           └── 0| Race - Ethnicity= White
# │       │       └── (Part of Target Population | Convicting Offense Type = Violent)
# │       │           ├── (Convicting Offense Classification | Part of Target Population = Yes)
# │       │           │   ├── (Race - Ethnicity | Convicting Offense Classification = D Felony)
# │       │           │   │   ├── 0| Race - Ethnicity= Black
# │       │           │   │   └── 0| Race - Ethnicity= White
# │       │           │   └── (Race - Ethnicity | Convicting Offense Classification = Other Felony)
# │       │           │       ├── 0| Race - Ethnicity= Black
# │       │           │       └── 0| Race - Ethnicity= White
# │       │           └── (Race - Ethnicity | Part of Target Population = No)
# │       │               ├── (Convicting Offense Classification | Race - Ethnicity = Black)
# │       │               │   ├── 0Convicting Offense Classification = D Felony
# │       │               │   └── 0| Convicting Offense Classification= Other Felony
# │       │               └── (Convicting Offense Classification | Race - Ethnicity = White)
# │       │                   ├── 0| Convicting Offense Classification= D Felony
# │       │                   └── 0| Convicting Offense Classification= Other Felony
# │       └── (Part of Target Population | Main Supervising District = 5JD)
# │           ├── (Age At Release | Part of Target Population = No)
# │           │   ├── (Convicting Offense Type | Age At Release = <45)
# │           │   │   ├── (Convicting Offense Classification | Convicting Offense Type = Other)
# │           │   │   │   ├── (Race - Ethnicity | Convicting Offense Classification = D Felony)
# │           │   │   │   │   ├── 0| Race - Ethnicity= White
# │           │   │   │   │   └── 1Race - Ethnicity = Black
# │           │   │   │   └── (Race - Ethnicity | Convicting Offense Classification = Other Felony)
# │           │   │   │       ├── 0| Race - Ethnicity= Black
# │           │   │   │       └── 0| Race - Ethnicity= White
# │           │   │   ├── (Convicting Offense Classification | Convicting Offense Type = Violent)
# │           │   │   │   ├── (Race - Ethnicity | Convicting Offense Classification = D Felony)
# │           │   │   │   │   ├── 0Race - Ethnicity = Black
# │           │   │   │   │   └── 0| Race - Ethnicity= White
# │           │   │   │   └── (Race - Ethnicity | Convicting Offense Classification = Other Felony)
# │           │   │   │       ├── 0| Race - Ethnicity= Black
# │           │   │   │       └── 0| Race - Ethnicity= White
# │           │   │   └── (Race - Ethnicity | Convicting Offense Type = Drug)
# │           │   │       ├── (Convicting Offense Classification | Race - Ethnicity = White)
# │           │   │       │   ├── (Fiscal Year Released | Convicting Offense Classification = D Felony)
# │           │   │       │   │   └── (Convicting Offense Subtype | Fiscal Year Released = 2015)
# │           │   │       │   │       ├── 0| Convicting Offense Subtype= Other
# │           │   │       │   │       └── 0| Convicting Offense Subtype= Trafficking
# │           │   │       │   └── 0| Convicting Offense Classification= Other Felony
# │           │   │       └── 0Race - Ethnicity = Black
# │           │   └── (Convicting Offense Type | Age At Release = >45)
# │           │       ├── (Race - Ethnicity | Convicting Offense Type = Drug)
# │           │       │   └── (Convicting Offense Classification | Race - Ethnicity = White)
# │           │       │       ├── 0| Convicting Offense Classification= D Felony
# │           │       │       └── 0| Convicting Offense Classification= Other Felony
# │           │       ├── (Race - Ethnicity | Convicting Offense Type = Other)
# │           │       │   ├── (Convicting Offense Classification | Race - Ethnicity = Black)
# │           │       │   │   ├── 0Convicting Offense Classification = D Felony
# │           │       │   │   └── 0| Convicting Offense Classification= Other Felony
# │           │       │   └── (Convicting Offense Classification | Race - Ethnicity = White)
# │           │       │       ├── 0Convicting Offense Classification = Other Felony
# │           │       │       └── 0| Convicting Offense Classification= D Felony
# │           │       └── 0Convicting Offense Type = Violent
# │           └── (Race - Ethnicity | Part of Target Population = Yes)
# │               ├── (Age At Release | Race - Ethnicity = Black)
# │               │   ├── (Convicting Offense Type | Age At Release = <45)
# │               │   │   ├── (Convicting Offense Classification | Convicting Offense Type = Other)
# │               │   │   │   ├── 0| Convicting Offense Classification= D Felony
# │               │   │   │   └── 0| Convicting Offense Classification= Other Felony
# │               │   │   ├── (Convicting Offense Classification | Convicting Offense Type = Violent)
# │               │   │   │   ├── 0| Convicting Offense Classification= D Felony
# │               │   │   │   └── 0| Convicting Offense Classification= Other Felony
# │               │   │   └── (Convicting Offense Subtype | Convicting Offense Type = Drug)
# │               │   │       ├── (Convicting Offense Classification | Convicting Offense Subtype = Trafficking)
# │               │   │       │   ├── 0| Convicting Offense Classification= D Felony
# │               │   │       │   └── 0| Convicting Offense Classification= Other Felony
# │               │   │       └── 1Convicting Offense Subtype = Other
# │               │   └── (Convicting Offense Type | Age At Release = >45)
# │               │       ├── (Convicting Offense Classification | Convicting Offense Type = Other)
# │               │       │   ├── 0| Convicting Offense Classification= D Felony
# │               │       │   └── 0| Convicting Offense Classification= Other Felony
# │               │       └── 0Convicting Offense Type = Violent
# │               └── (Age At Release | Race - Ethnicity = White)
# │                   ├── (Convicting Offense Classification | Age At Release = >45)
# │                   │   ├── (Convicting Offense Type | Convicting Offense Classification = D Felony)
# │                   │   │   ├── 0| Convicting Offense Type= Other
# │                   │   │   └── 1Convicting Offense Type = Violent
# │                   │   └── (Convicting Offense Type | Convicting Offense Classification = Other Felony)
# │                   │       ├── 0| Convicting Offense Type= Other
# │                   │       ├── 0| Convicting Offense Type= Violent
# │                   │       └── 1Convicting Offense Type = Drug
# │                   └── (Convicting Offense Type | Age At Release = <45)
# │                       ├── (Convicting Offense Classification | Convicting Offense Type = Drug)
# │                       │   ├── (Convicting Offense Subtype | Convicting Offense Classification = D Felony)
# │                       │   │   ├── 0| Convicting Offense Subtype= Other
# │                       │   │   └── 0| Convicting Offense Subtype= Trafficking
# │                       │   └── (Convicting Offense Subtype | Convicting Offense Classification = Other Felony)
# │                       │       ├── 0| Convicting Offense Subtype= Other
# │                       │       └── 0| Convicting Offense Subtype= Trafficking
# │                       ├── (Convicting Offense Classification | Convicting Offense Type = Other)
# │                       │   ├── 0| Convicting Offense Classification= D Felony
# │                       │   └── 0| Convicting Offense Classification= Other Felony
# │                       └── (Convicting Offense Classification | Convicting Offense Type = Violent)
# │                           ├── 0| Convicting Offense Classification= D Felony
# │                           └── 0| Convicting Offense Classification= Other Felony
# └── 1Recidivism Reporting Year = 2013

# %%
print(out_str)
# Out:
# iteration : 0
# root: {'name': '', 'value': ''}
# Entropy class : 0.9885815658559858
# Info_gain of Race - Ethnicity= 5.732673222835771e-05
# Info_gain of Convicting Offense Type= 0.00355540535576937
# Info_gain of Age At Release= 0.006670108151095477
# Info_gain of Release Type= 0.009453934793683172
# Info_gain of Main Supervising District= 0.009184459572582071
# Info_gain of Part of Target Population= 0.01672136288497783
# Info_gain of Convicting Offense Subtype= 0.0010336861301879496
# Info_gain of Recidivism Reporting Year= 0.21700574276244844
# Info_gain of Convicting Offense Classification= 0.0008671111607267967
# Info_gain of Fiscal Year Released= 0.21700574276244844
# Best variable: Recidivism Reporting Year
# --------------------------------------------------
# iteration : 1
# root: {'name': 'Recidivism Reporting Year', 'value': 2013}
# all the classes are the same, leaf = 1
# --------------------------------------------------
# iteration : 2
# root: {'name': 'Recidivism Reporting Year', 'value': 2016}
# Entropy class : 0.8173890576591973
# Info_gain of Age At Release= 0.007509818286024261
# Info_gain of Convicting Offense Classification= 0.0007296656808841728
# Info_gain of Release Type= 0.00030923429562568217
# Info_gain of Race - Ethnicity= 0.00026452839403712236
# Info_gain of Convicting Offense Subtype= 0.0007061050871401964
# Info_gain of Convicting Offense Type= 0.004624424437761676
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Main Supervising District= 0.005090222700986913
# Info_gain of Part of Target Population= 2.8000515568504802e-05
# Best variable: Age At Release
# --------------------------------------------------
# iteration : 3
# root: {'name': 'Age At Release', 'value': '<45'}
# Entropy class : 0.7801872143131084
# Info_gain of Race - Ethnicity= 6.120044644453149e-05
# Info_gain of Convicting Offense Subtype= 0.0006405262597979355
# Info_gain of Convicting Offense Classification= 0.0018535687013503388
# Info_gain of Convicting Offense Type= 0.0033477572254833055
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Main Supervising District= 0.005557949262563144
# Info_gain of Part of Target Population= 5.563375257489067e-05
# Info_gain of Release Type= 0.000818728717900119
# Best variable: Main Supervising District
# --------------------------------------------------
# iteration : 4
# root: {'name': 'Main Supervising District', 'value': '3JD'}
# Entropy class : 0.827290336116174
# Info_gain of Race - Ethnicity= 0.00010794094585875325
# Info_gain of Convicting Offense Type= 0.0036008148892699987
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Release Type= 1.7998542356512104e-07
# Info_gain of Convicting Offense Subtype= 7.498716961595875e-06
# Info_gain of Part of Target Population= 0.0007988255074707906
# Info_gain of Convicting Offense Classification= 0.0017352497179617954
# Best variable: Convicting Offense Type
# --------------------------------------------------
# iteration : 5
# root: {'name': 'Convicting Offense Type', 'value': 'Drug'}
# Entropy class : 0.8134362025233061
# Info_gain of Race - Ethnicity= 0.0011122899464464098
# Info_gain of Convicting Offense Subtype= 0.0007538753155199585
# Info_gain of Convicting Offense Classification= 1.7830251516026685e-05
# Info_gain of Release Type= 0.010145358246472669
# Info_gain of Part of Target Population= 0.0013603076219028676
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Release Type
# --------------------------------------------------
# iteration : 6
# root: {'name': 'Release Type', 'value': 'Discharged End of Sentence'}
# Entropy class : 0.9182958340544896
# Info_gain of Race - Ethnicity= 0.0011205621641601216
# Info_gain of Part of Target Population= 0.027865958268803115
# Info_gain of Convicting Offense Subtype= 0.004470359453144446
# Info_gain of Convicting Offense Classification= 0.018669606563397112
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Part of Target Population
# --------------------------------------------------
# iteration : 7
# root: {'name': 'Part of Target Population', 'value': 'No'}
# Entropy class : 0.8739810481273578
# Info_gain of Convicting Offense Subtype= 0.0016318298784363527
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Classification= 0.014436633205938132
# Info_gain of Race - Ethnicity= 0.00010997281687563643
# Best variable: Convicting Offense Classification
# --------------------------------------------------
# iteration : 8
# root: {'name': 'Convicting Offense Classification', 'value': 'D Felony'}
# Entropy class : 0.7382848661434506
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Race - Ethnicity= 0.09898098215634155
# Info_gain of Convicting Offense Subtype= 0.0310704099259701
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 9
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# all the classes are the same, leaf = 1
# --------------------------------------------------
# iteration : 10
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# Entropy class : 0.8524051786494786
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Subtype= 0.03383295135345454
# Best variable: Convicting Offense Subtype
# --------------------------------------------------
# iteration : 11
# root: {'name': 'Convicting Offense Subtype', 'value': 'Other'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 12
# root: {'name': 'Convicting Offense Subtype', 'value': 'Trafficking'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 13
# root: {'name': 'Convicting Offense Classification', 'value': 'Other Felony'}
# Entropy class : 0.9256859869821299
# Info_gain of Race - Ethnicity= 0.005735512782321761
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Subtype= 0.012287482304932817
# Best variable: Convicting Offense Subtype
# --------------------------------------------------
# iteration : 14
# root: {'name': 'Convicting Offense Subtype', 'value': 'Other'}
# Entropy class : 0.7642045065086203
# Info_gain of Race - Ethnicity= 0.009548455093403407
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 15
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 16
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 17
# root: {'name': 'Convicting Offense Subtype', 'value': 'Trafficking'}
# Entropy class : 0.9517626756348311
# Info_gain of Race - Ethnicity= 0.0025012120083610645
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 18
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 19
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 20
# root: {'name': 'Part of Target Population', 'value': 'Yes'}
# Entropy class : 0.9876925088958034
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Subtype= 0.022119868077478677
# Info_gain of Race - Ethnicity= 0.0026109893124183214
# Info_gain of Convicting Offense Classification= 0.05682687697332234
# Best variable: Convicting Offense Classification
# --------------------------------------------------
# iteration : 21
# root: {'name': 'Convicting Offense Classification', 'value': 'D Felony'}
# Entropy class : 0.9544340029249649
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Race - Ethnicity= 0.0
# Info_gain of Convicting Offense Subtype= 0.0032289436203634114
# Best variable: Convicting Offense Subtype
# --------------------------------------------------
# iteration : 22
# root: {'name': 'Convicting Offense Subtype', 'value': 'Other'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 23
# root: {'name': 'Convicting Offense Subtype', 'value': 'Trafficking'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 24
# root: {'name': 'Convicting Offense Classification', 'value': 'Other Felony'}
# Entropy class : 0.9182958340544896
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Race - Ethnicity= 0.03170514719803608
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 25
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 26
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 27
# root: {'name': 'Release Type', 'value': 'Parole'}
# Entropy class : 0.7564041945982505
# Info_gain of Convicting Offense Subtype= 0.001649817438784229
# Info_gain of Convicting Offense Classification= 0.003495363569627319
# Info_gain of Race - Ethnicity= 0.0011087283682729154
# Info_gain of Part of Target Population= 0.004580353627218203
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Part of Target Population
# --------------------------------------------------
# iteration : 28
# root: {'name': 'Part of Target Population', 'value': 'No'}
# all the classes are the same, leaf = 1
# --------------------------------------------------
# iteration : 29
# root: {'name': 'Part of Target Population', 'value': 'Yes'}
# Entropy class : 0.761587786957669
# Info_gain of Race - Ethnicity= 0.00087969102960328
# Info_gain of Convicting Offense Subtype= 0.0018509233823399418
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Classification= 0.003139249661374355
# Best variable: Convicting Offense Classification
# --------------------------------------------------
# iteration : 30
# root: {'name': 'Convicting Offense Classification', 'value': 'D Felony'}
# Entropy class : 0.837602456861142
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Race - Ethnicity= 4.624114363860343e-06
# Info_gain of Convicting Offense Subtype= 0.046136335221791724
# Best variable: Convicting Offense Subtype
# --------------------------------------------------
# iteration : 31
# root: {'name': 'Convicting Offense Subtype', 'value': 'Other'}
# Entropy class : 0.5225593745369408
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Race - Ethnicity= 0.0010980660363900663
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 32
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 33
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 34
# root: {'name': 'Convicting Offense Subtype', 'value': 'Trafficking'}
# Entropy class : 0.927926261959976
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Race - Ethnicity= 0.0009654033535047013
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 35
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 36
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 37
# root: {'name': 'Convicting Offense Classification', 'value': 'Other Felony'}
# Entropy class : 0.7302987278735849
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Subtype= 0.001410440621751552
# Info_gain of Race - Ethnicity= 0.0014915858140269744
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 38
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# Entropy class : 0.672294817075638
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Subtype= 0.019651750101551846
# Best variable: Convicting Offense Subtype
# --------------------------------------------------
# iteration : 39
# root: {'name': 'Convicting Offense Subtype', 'value': 'Other'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 40
# root: {'name': 'Convicting Offense Subtype', 'value': 'Trafficking'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 41
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# Entropy class : 0.7529455723290713
# Info_gain of Convicting Offense Subtype= 5.9296830426269764e-05
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Convicting Offense Subtype
# --------------------------------------------------
# iteration : 42
# root: {'name': 'Convicting Offense Subtype', 'value': 'Other'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 43
# root: {'name': 'Convicting Offense Subtype', 'value': 'Trafficking'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 44
# root: {'name': 'Convicting Offense Type', 'value': 'Other'}
# Entropy class : 0.7940114549572396
# Info_gain of Part of Target Population= 0.0037277260886385832
# Info_gain of Convicting Offense Classification= 0.0034994011161781913
# Info_gain of Race - Ethnicity= 0.00014667120664946243
# Info_gain of Release Type= 0.0007298114402006783
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Part of Target Population
# --------------------------------------------------
# iteration : 45
# root: {'name': 'Part of Target Population', 'value': 'No'}
# Entropy class : 0.7356455437394886
# Info_gain of Release Type= 0.006234871620362403
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Classification= 0.001094314641325811
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Race - Ethnicity= 0.0006957814489125802
# Best variable: Release Type
# --------------------------------------------------
# iteration : 46
# root: {'name': 'Release Type', 'value': 'Discharged End of Sentence'}
# Entropy class : 0.743115674309256
# Info_gain of Convicting Offense Classification= 0.0012922810951365715
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Race - Ethnicity= 0.0007890999423676437
# Info_gain of Convicting Offense Subtype= 0.0
# Best variable: Convicting Offense Classification
# --------------------------------------------------
# iteration : 47
# root: {'name': 'Convicting Offense Classification', 'value': 'D Felony'}
# Entropy class : 0.7738785654282403
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Race - Ethnicity= 0.0009225636302118145
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 48
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 49
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 50
# root: {'name': 'Convicting Offense Classification', 'value': 'Other Felony'}
# Entropy class : 0.7079797349966357
# Info_gain of Race - Ethnicity= 0.008571941500731484
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 51
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 52
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 53
# root: {'name': 'Release Type', 'value': 'Parole'}
# all the classes are the same, leaf = 1
# --------------------------------------------------
# iteration : 54
# root: {'name': 'Part of Target Population', 'value': 'Yes'}
# Entropy class : 0.8389396309543797
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Race - Ethnicity= 0.0020770532156263455
# Info_gain of Convicting Offense Classification= 0.0067229177388794525
# Info_gain of Release Type= 0.002876816049072861
# Best variable: Convicting Offense Classification
# --------------------------------------------------
# iteration : 55
# root: {'name': 'Convicting Offense Classification', 'value': 'D Felony'}
# Entropy class : 0.8937144582542121
# Info_gain of Race - Ethnicity= 0.00016497749581634302
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Release Type= 0.013622536978703415
# Info_gain of Convicting Offense Subtype= 0.0
# Best variable: Release Type
# --------------------------------------------------
# iteration : 56
# root: {'name': 'Release Type', 'value': 'Discharged End of Sentence'}
# Entropy class : 0.9988455359952018
# Info_gain of Race - Ethnicity= 0.00010044896931571401
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Subtype= 0.0
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 57
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 58
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 59
# root: {'name': 'Release Type', 'value': 'Parole'}
# Entropy class : 0.8683108087041105
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Race - Ethnicity= 1.3597008614585349e-06
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 60
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 61
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 62
# root: {'name': 'Convicting Offense Classification', 'value': 'Other Felony'}
# Entropy class : 0.7693573944858945
# Info_gain of Release Type= 7.401178789834262e-06
# Info_gain of Race - Ethnicity= 0.002319751368143108
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Subtype= 0.0
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 63
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# Entropy class : 0.7095128863456241
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Release Type= 0.014595334070779842
# Best variable: Release Type
# --------------------------------------------------
# iteration : 64
# root: {'name': 'Release Type', 'value': 'Discharged End of Sentence'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 65
# root: {'name': 'Release Type', 'value': 'Parole'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 66
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# Entropy class : 0.7996239215204592
# Info_gain of Release Type= 0.0021607503797622662
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Release Type
# --------------------------------------------------
# iteration : 67
# root: {'name': 'Release Type', 'value': 'Discharged End of Sentence'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 68
# root: {'name': 'Release Type', 'value': 'Parole'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 69
# root: {'name': 'Convicting Offense Type', 'value': 'Violent'}
# Entropy class : 0.9017486384450322
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Release Type= 0.008893953062174331
# Info_gain of Race - Ethnicity= 0.00023169548480828084
# Info_gain of Convicting Offense Classification= 0.006068198119906443
# Info_gain of Part of Target Population= 0.0021066167570894523
# Best variable: Release Type
# --------------------------------------------------
# iteration : 70
# root: {'name': 'Release Type', 'value': 'Discharged End of Sentence'}
# Entropy class : 0.8570132543961471
# Info_gain of Convicting Offense Classification= 0.02638384281206896
# Info_gain of Race - Ethnicity= 0.002465190490918978
# Info_gain of Part of Target Population= 0.00221845260089637
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Convicting Offense Classification
# --------------------------------------------------
# iteration : 71
# root: {'name': 'Convicting Offense Classification', 'value': 'D Felony'}
# Entropy class : 0.9789987370022761
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Race - Ethnicity= 0.033608989981817716
# Info_gain of Part of Target Population= 0.004770804622764135
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 72
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 73
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# Entropy class : 0.9967916319816366
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Part of Target Population= 0.016569376727522123
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Part of Target Population
# --------------------------------------------------
# iteration : 74
# root: {'name': 'Part of Target Population', 'value': 'No'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 75
# root: {'name': 'Part of Target Population', 'value': 'Yes'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 76
# root: {'name': 'Convicting Offense Classification', 'value': 'Other Felony'}
# Entropy class : 0.7669457741899657
# Info_gain of Part of Target Population= 0.0005541875266545926
# Info_gain of Race - Ethnicity= 0.029786061780897488
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 77
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# Entropy class : 0.9421631690835512
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Part of Target Population= 0.006177383008618698
# Info_gain of Convicting Offense Subtype= 0.0
# Best variable: Part of Target Population
# --------------------------------------------------
# iteration : 78
# root: {'name': 'Part of Target Population', 'value': 'No'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 79
# root: {'name': 'Part of Target Population', 'value': 'Yes'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 80
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# Entropy class : 0.652513123846701
# Info_gain of Part of Target Population= 2.682543006171656e-06
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Part of Target Population
# --------------------------------------------------
# iteration : 81
# root: {'name': 'Part of Target Population', 'value': 'No'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 82
# root: {'name': 'Part of Target Population', 'value': 'Yes'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 83
# root: {'name': 'Release Type', 'value': 'Parole'}
# Entropy class : 0.966177351388351
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Race - Ethnicity= 0.0040357215855948425
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Convicting Offense Classification= 0.010080791835595071
# Info_gain of Part of Target Population= 0.0047143033513005195
# Best variable: Convicting Offense Classification
# --------------------------------------------------
# iteration : 84
# root: {'name': 'Convicting Offense Classification', 'value': 'D Felony'}
# Entropy class : 0.907165767573082
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Part of Target Population= 0.0
# Info_gain of Race - Ethnicity= 0.045592597552843284
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 85
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 86
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 87
# root: {'name': 'Convicting Offense Classification', 'value': 'Other Felony'}
# Entropy class : 0.9894340222202263
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Part of Target Population= 0.009248908094511954
# Info_gain of Race - Ethnicity= 0.0018890875528358997
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Part of Target Population
# --------------------------------------------------
# iteration : 88
# root: {'name': 'Part of Target Population', 'value': 'No'}
# all the classes are the same, leaf = 1
# --------------------------------------------------
# iteration : 89
# root: {'name': 'Part of Target Population', 'value': 'Yes'}
# Entropy class : 0.9910760598382222
# Info_gain of Race - Ethnicity= 0.0026161552699859314
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Subtype= 0.0
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 90
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 91
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 92
# root: {'name': 'Main Supervising District', 'value': '5JD'}
# Entropy class : 0.691289869405789
# Info_gain of Convicting Offense Subtype= 0.0015924562378294427
# Info_gain of Release Type= 0.0002539183753273999
# Info_gain of Convicting Offense Classification= 0.0013015544591135075
# Info_gain of Convicting Offense Type= 0.0025192199750428967
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Race - Ethnicity= 0.0001062271331340181
# Info_gain of Part of Target Population= 0.005063300684461813
# Best variable: Part of Target Population
# --------------------------------------------------
# iteration : 93
# root: {'name': 'Part of Target Population', 'value': 'No'}
# all the classes are the same, leaf = 1
# --------------------------------------------------
# iteration : 94
# root: {'name': 'Part of Target Population', 'value': 'Yes'}
# Entropy class : 0.6980766350571742
# Info_gain of Convicting Offense Type= 0.0026444200755600944
# Info_gain of Convicting Offense Subtype= 0.001801229707296792
# Info_gain of Race - Ethnicity= 0.00011576122610934547
# Info_gain of Convicting Offense Classification= 0.00143282896088881
# Info_gain of Release Type= 0.0002827351260301647
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Convicting Offense Type
# --------------------------------------------------
# iteration : 95
# root: {'name': 'Convicting Offense Type', 'value': 'Drug'}
# Entropy class : 0.6331341171926692
# Info_gain of Convicting Offense Subtype= 4.250178993092657e-05
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Classification= 0.00011044483880129352
# Info_gain of Race - Ethnicity= 0.002067990193807878
# Info_gain of Release Type= 0.002474548139306365
# Best variable: Release Type
# --------------------------------------------------
# iteration : 96
# root: {'name': 'Release Type', 'value': 'Discharged End of Sentence'}
# Entropy class : 0.9709505944546686
# Info_gain of Race - Ethnicity= 0.17095059445466854
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Convicting Offense Classification= 0.17095059445466854
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 97
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# all the classes are the same, leaf = 1
# --------------------------------------------------
# iteration : 98
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# Entropy class : 1.0
# Info_gain of Convicting Offense Classification= 0.31127812445913283
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Convicting Offense Classification
# --------------------------------------------------
# iteration : 99
# root: {'name': 'Convicting Offense Classification', 'value': 'D Felony'}
# all the classes are the same, leaf = 1
# --------------------------------------------------
# iteration : 100
# root: {'name': 'Convicting Offense Classification', 'value': 'Other Felony'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 101
# root: {'name': 'Release Type', 'value': 'Parole'}
# Entropy class : 0.6271441658983906
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Classification= 3.275073666997308e-05
# Info_gain of Race - Ethnicity= 0.002608627274655606
# Info_gain of Convicting Offense Subtype= 1.728322177885211e-05
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 102
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# Entropy class : 0.7150375653354625
# Info_gain of Convicting Offense Classification= 0.0016580578488714082
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Subtype= 0.0002431997368396166
# Best variable: Convicting Offense Classification
# --------------------------------------------------
# iteration : 103
# root: {'name': 'Convicting Offense Classification', 'value': 'D Felony'}
# Entropy class : 0.7918583525674836
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Subtype= 0.01382518934665633
# Best variable: Convicting Offense Subtype
# --------------------------------------------------
# iteration : 104
# root: {'name': 'Convicting Offense Subtype', 'value': 'Other'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 105
# root: {'name': 'Convicting Offense Subtype', 'value': 'Trafficking'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 106
# root: {'name': 'Convicting Offense Classification', 'value': 'Other Felony'}
# Entropy class : 0.6962122601251458
# Info_gain of Convicting Offense Subtype= 0.009527701584580828
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Convicting Offense Subtype
# --------------------------------------------------
# iteration : 107
# root: {'name': 'Convicting Offense Subtype', 'value': 'Other'}
# all the classes are the same, leaf = 1
# --------------------------------------------------
# iteration : 108
# root: {'name': 'Convicting Offense Subtype', 'value': 'Trafficking'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 109
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# Entropy class : 0.5956833938682252
# Info_gain of Convicting Offense Subtype= 2.9401077418222954e-06
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Classification= 0.00032005914490540466
# Best variable: Convicting Offense Classification
# --------------------------------------------------
# iteration : 110
# root: {'name': 'Convicting Offense Classification', 'value': 'D Felony'}
# Entropy class : 0.5600443203590992
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Subtype= 0.005621251758710422
# Best variable: Convicting Offense Subtype
# --------------------------------------------------
# iteration : 111
# root: {'name': 'Convicting Offense Subtype', 'value': 'Other'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 112
# root: {'name': 'Convicting Offense Subtype', 'value': 'Trafficking'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 113
# root: {'name': 'Convicting Offense Classification', 'value': 'Other Felony'}
# Entropy class : 0.6058467170787776
# Info_gain of Convicting Offense Subtype= 0.0008619152421054377
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Convicting Offense Subtype
# --------------------------------------------------
# iteration : 114
# root: {'name': 'Convicting Offense Subtype', 'value': 'Other'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 115
# root: {'name': 'Convicting Offense Subtype', 'value': 'Trafficking'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 116
# root: {'name': 'Convicting Offense Type', 'value': 'Other'}
# Entropy class : 0.7259841316077185
# Info_gain of Race - Ethnicity= 0.003975833460214462
# Info_gain of Release Type= 0.0001001714707171697
# Info_gain of Convicting Offense Classification= 0.0009991112052707418
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Subtype= 0.0
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 117
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# Entropy class : 0.6098403047164004
# Info_gain of Convicting Offense Classification= 0.0013360175605283686
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Release Type= 0.0006330536322732838
# Info_gain of Convicting Offense Subtype= 0.0
# Best variable: Convicting Offense Classification
# --------------------------------------------------
# iteration : 118
# root: {'name': 'Convicting Offense Classification', 'value': 'D Felony'}
# Entropy class : 0.6572729784684463
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Release Type= 0.005119093974752409
# Best variable: Release Type
# --------------------------------------------------
# iteration : 119
# root: {'name': 'Release Type', 'value': 'Discharged End of Sentence'}
# all the classes are the same, leaf = 1
# --------------------------------------------------
# iteration : 120
# root: {'name': 'Release Type', 'value': 'Parole'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 121
# root: {'name': 'Convicting Offense Classification', 'value': 'Other Felony'}
# Entropy class : 0.5787946246321198
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Release Type= 0.00010527243034330613
# Best variable: Release Type
# --------------------------------------------------
# iteration : 122
# root: {'name': 'Release Type', 'value': 'Discharged End of Sentence'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 123
# root: {'name': 'Release Type', 'value': 'Parole'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 124
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# Entropy class : 0.7569827281705652
# Info_gain of Convicting Offense Classification= 0.00040201064180811485
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Release Type= 3.816511297893843e-05
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Convicting Offense Classification
# --------------------------------------------------
# iteration : 125
# root: {'name': 'Convicting Offense Classification', 'value': 'D Felony'}
# Entropy class : 0.7732266742876346
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Release Type= 0.0009656775357181901
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Release Type
# --------------------------------------------------
# iteration : 126
# root: {'name': 'Release Type', 'value': 'Discharged End of Sentence'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 127
# root: {'name': 'Release Type', 'value': 'Parole'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 128
# root: {'name': 'Convicting Offense Classification', 'value': 'Other Felony'}
# Entropy class : 0.7371202270183788
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Release Type= 0.00019521818724888007
# Info_gain of Convicting Offense Subtype= 0.0
# Best variable: Release Type
# --------------------------------------------------
# iteration : 129
# root: {'name': 'Release Type', 'value': 'Discharged End of Sentence'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 130
# root: {'name': 'Release Type', 'value': 'Parole'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 131
# root: {'name': 'Convicting Offense Type', 'value': 'Violent'}
# Entropy class : 0.7590479850123208
# Info_gain of Convicting Offense Classification= 0.010313840141795705
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Release Type= 0.015677765972041957
# Info_gain of Race - Ethnicity= 1.6403679039544983e-06
# Best variable: Release Type
# --------------------------------------------------
# iteration : 132
# root: {'name': 'Release Type', 'value': 'Discharged End of Sentence'}
# Entropy class : 0.5293608652873644
# Info_gain of Convicting Offense Classification= 0.0005567069478955577
# Info_gain of Race - Ethnicity= 0.00012053176812065747
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Subtype= 0.0
# Best variable: Convicting Offense Classification
# --------------------------------------------------
# iteration : 133
# root: {'name': 'Convicting Offense Classification', 'value': 'D Felony'}
# Entropy class : 0.5916727785823275
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Race - Ethnicity= 0.03451070288373825
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 134
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# all the classes are the same, leaf = 1
# --------------------------------------------------
# iteration : 135
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 136
# root: {'name': 'Convicting Offense Classification', 'value': 'Other Felony'}
# Entropy class : 0.5185697317883058
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Race - Ethnicity= 0.00012006860975999345
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 137
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 138
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 139
# root: {'name': 'Release Type', 'value': 'Parole'}
# Entropy class : 0.8166610936131946
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Race - Ethnicity= 0.0003599716319853119
# Info_gain of Convicting Offense Classification= 0.008610372449422865
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Convicting Offense Classification
# --------------------------------------------------
# iteration : 140
# root: {'name': 'Convicting Offense Classification', 'value': 'D Felony'}
# Entropy class : 0.904381457724494
# Info_gain of Race - Ethnicity= 0.06579671998146641
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 141
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 142
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 143
# root: {'name': 'Convicting Offense Classification', 'value': 'Other Felony'}
# Entropy class : 0.7578784625383955
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Race - Ethnicity= 0.012794226759646699
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 144
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 145
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 146
# root: {'name': 'Age At Release', 'value': '>45'}
# Entropy class : 0.9299024372910913
# Info_gain of Release Type= 3.264400475599949e-06
# Info_gain of Main Supervising District= 0.004818134471072488
# Info_gain of Convicting Offense Subtype= 0.0005763780068994695
# Info_gain of Convicting Offense Type= 0.016059301733898135
# Info_gain of Convicting Offense Classification= 7.797755259453254e-05
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Part of Target Population= 0.001422493847623607
# Info_gain of Race - Ethnicity= 0.0025670361822526244
# Best variable: Convicting Offense Type
# --------------------------------------------------
# iteration : 147
# root: {'name': 'Convicting Offense Type', 'value': 'Drug'}
# Entropy class : 0.8995203955997693
# Info_gain of Race - Ethnicity= 0.00881746667986505
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Part of Target Population= 0.0017774715856793133
# Info_gain of Convicting Offense Subtype= 0.00037901994934930183
# Info_gain of Main Supervising District= 0.00011280448680461852
# Info_gain of Convicting Offense Classification= 0.004011602371667422
# Info_gain of Release Type= 0.0003489911806821011
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 148
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# Entropy class : 0.7568336324184035
# Info_gain of Convicting Offense Subtype= 0.005742371715526495
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Classification= 0.0014446058604874468
# Info_gain of Main Supervising District= 0.015503901593103775
# Info_gain of Part of Target Population= 0.010751421627143376
# Info_gain of Release Type= 0.010751421627143376
# Best variable: Main Supervising District
# --------------------------------------------------
# iteration : 149
# root: {'name': 'Main Supervising District', 'value': '3JD'}
# Entropy class : 0.833764907210665
# Info_gain of Release Type= 0.03556309967851312
# Info_gain of Part of Target Population= 0.03556309967851312
# Info_gain of Convicting Offense Classification= 0.0028112761876522008
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Subtype= 0.06102864511301298
# Best variable: Convicting Offense Subtype
# --------------------------------------------------
# iteration : 150
# root: {'name': 'Convicting Offense Subtype', 'value': 'Other'}
# Entropy class : 0.4394969869215134
# Info_gain of Convicting Offense Classification= 0.06297794600548684
# Info_gain of Release Type= 0.11134785288180327
# Info_gain of Part of Target Population= 0.11134785288180327
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Release Type
# --------------------------------------------------
# iteration : 151
# root: {'name': 'Release Type', 'value': 'Discharged End of Sentence'}
# all the classes are the same, leaf = 1
# --------------------------------------------------
# iteration : 152
# root: {'name': 'Release Type', 'value': 'Parole'}
# Entropy class : 0.7219280948873623
# Info_gain of Convicting Offense Classification= 0.17095059445466865
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Part of Target Population= 0.0
# Best variable: Convicting Offense Classification
# --------------------------------------------------
# iteration : 153
# root: {'name': 'Convicting Offense Classification', 'value': 'D Felony'}
# all the classes are the same, leaf = 1
# --------------------------------------------------
# iteration : 154
# root: {'name': 'Convicting Offense Classification', 'value': 'Other Felony'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 155
# root: {'name': 'Convicting Offense Subtype', 'value': 'Trafficking'}
# Entropy class : 0.9321115676166747
# Info_gain of Part of Target Population= 0.00010075850044488632
# Info_gain of Convicting Offense Classification= 0.06895277537799926
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Release Type= 0.00010075850044488632
# Best variable: Convicting Offense Classification
# --------------------------------------------------
# iteration : 156
# root: {'name': 'Convicting Offense Classification', 'value': 'D Felony'}
# all the classes are the same, leaf = 0
# --------------------------------------------------
# iteration : 157
# root: {'name': 'Convicting Offense Classification', 'value': 'Other Felony'}
# Entropy class : 0.9023932827949789
# Info_gain of Release Type= 0.05324050518089618
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Part of Target Population= 0.05324050518089618
# Best variable: Release Type
# --------------------------------------------------
# iteration : 158
# root: {'name': 'Release Type', 'value': 'Discharged End of Sentence'}
# all the classes are the same, leaf = 1
# --------------------------------------------------
# iteration : 159
# root: {'name': 'Release Type', 'value': 'Parole'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 160
# root: {'name': 'Main Supervising District', 'value': '5JD'}
# Entropy class : 0.5916727785823275
# Info_gain of Convicting Offense Classification= 0.0013024391450082717
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Part of Target Population= 0.0
# Info_gain of Release Type= 0.0
# Info_gain of Convicting Offense Subtype= 0.057208280764596386
# Best variable: Convicting Offense Subtype
# --------------------------------------------------
# iteration : 161
# root: {'name': 'Convicting Offense Subtype', 'value': 'Other'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 162
# root: {'name': 'Convicting Offense Subtype', 'value': 'Trafficking'}
# Entropy class : 0.4854607607459134
# Info_gain of Release Type= 0.0
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Classification= 0.03821641346730392
# Info_gain of Part of Target Population= 0.0
# Best variable: Convicting Offense Classification
# --------------------------------------------------
# iteration : 163
# root: {'name': 'Convicting Offense Classification', 'value': 'D Felony'}
# all the classes are the same, leaf = 1
# --------------------------------------------------
# iteration : 164
# root: {'name': 'Convicting Offense Classification', 'value': 'Other Felony'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 165
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# Entropy class : 0.9261010602063586
# Info_gain of Part of Target Population= 0.00021308300334110797
# Info_gain of Convicting Offense Subtype= 6.709051373543495e-05
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Release Type= 0.0038859083305110564
# Info_gain of Main Supervising District= 3.2902689811709074e-05
# Info_gain of Convicting Offense Classification= 0.0050921567063781925
# Best variable: Convicting Offense Classification
# --------------------------------------------------
# iteration : 166
# ...
# Info_gain of Convicting Offense Classification= 0.011727832852289177
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Convicting Offense Classification
# --------------------------------------------------
# iteration : 631
# root: {'name': 'Convicting Offense Classification', 'value': 'D Felony'}
# Entropy class : 0.4394969869215134
# Info_gain of Race - Ethnicity= 0.013137356385803212
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 632
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# all the classes are the same, leaf = 0
# --------------------------------------------------
# iteration : 633
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 634
# root: {'name': 'Convicting Offense Classification', 'value': 'Other Felony'}
# Entropy class : 0.7088356733321961
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Race - Ethnicity= 0.0015232171181154275
# Info_gain of Convicting Offense Subtype= 0.0
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 635
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 636
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 637
# root: {'name': 'Part of Target Population', 'value': 'Yes'}
# Entropy class : 0.9731108053184281
# Info_gain of Race - Ethnicity= 5.556304644782628e-05
# Info_gain of Main Supervising District= 0.013664011030466439
# Info_gain of Convicting Offense Classification= 0.001679695916171342
# Info_gain of Convicting Offense Type= 0.002790416494192316
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Subtype= 0.000150829592393098
# Best variable: Main Supervising District
# --------------------------------------------------
# iteration : 638
# root: {'name': 'Main Supervising District', 'value': '3JD'}
# Entropy class : 0.9152073261515639
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Subtype= 0.0039025161689499877
# Info_gain of Convicting Offense Classification= 0.0072902287374242425
# Info_gain of Race - Ethnicity= 0.006493962198023118
# Info_gain of Convicting Offense Type= 0.003965163029803209
# Best variable: Convicting Offense Classification
# --------------------------------------------------
# iteration : 639
# root: {'name': 'Convicting Offense Classification', 'value': 'D Felony'}
# Entropy class : 0.8481636883083002
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Subtype= 0.012486856913171085
# Info_gain of Race - Ethnicity= 0.015919304470824125
# Info_gain of Convicting Offense Type= 0.0007117206707834001
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 640
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# Entropy class : 0.9656361333706098
# Info_gain of Convicting Offense Type= 0.000176054851302343
# Info_gain of Convicting Offense Subtype= 0.00155355114205169
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Convicting Offense Subtype
# --------------------------------------------------
# iteration : 641
# root: {'name': 'Convicting Offense Subtype', 'value': 'Other'}
# Entropy class : 0.9709505944546686
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Type= 0.0034091527711319625
# Best variable: Convicting Offense Type
# --------------------------------------------------
# iteration : 642
# root: {'name': 'Convicting Offense Type', 'value': 'Drug'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 643
# root: {'name': 'Convicting Offense Type', 'value': 'Other'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 644
# root: {'name': 'Convicting Offense Type', 'value': 'Violent'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 645
# root: {'name': 'Convicting Offense Subtype', 'value': 'Trafficking'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 646
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# Entropy class : 0.7871265862012691
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Subtype= 0.03600421465180326
# Info_gain of Convicting Offense Type= 0.00012068837206891114
# Best variable: Convicting Offense Subtype
# --------------------------------------------------
# iteration : 647
# root: {'name': 'Convicting Offense Subtype', 'value': 'Other'}
# Entropy class : 0.8238116333123173
# Info_gain of Convicting Offense Type= 0.01282050234734533
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Convicting Offense Type
# --------------------------------------------------
# iteration : 648
# root: {'name': 'Convicting Offense Type', 'value': 'Drug'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 649
# root: {'name': 'Convicting Offense Type', 'value': 'Other'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 650
# root: {'name': 'Convicting Offense Type', 'value': 'Violent'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 651
# root: {'name': 'Convicting Offense Subtype', 'value': 'Trafficking'}
# all the classes are the same, leaf = 0
# --------------------------------------------------
# iteration : 652
# root: {'name': 'Convicting Offense Classification', 'value': 'Other Felony'}
# Entropy class : 0.950732532285253
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Type= 0.018462373094366713
# Info_gain of Convicting Offense Subtype= 0.007385542755579455
# Info_gain of Race - Ethnicity= 0.0015135702490812752
# Best variable: Convicting Offense Type
# --------------------------------------------------
# iteration : 653
# root: {'name': 'Convicting Offense Type', 'value': 'Drug'}
# Entropy class : 0.8756633923230397
# Info_gain of Convicting Offense Subtype= 0.01164179577530211
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Race - Ethnicity= 0.001632199181723193
# Best variable: Convicting Offense Subtype
# --------------------------------------------------
# iteration : 654
# root: {'name': 'Convicting Offense Subtype', 'value': 'Other'}
# all the classes are the same, leaf = 0
# --------------------------------------------------
# iteration : 655
# root: {'name': 'Convicting Offense Subtype', 'value': 'Trafficking'}
# Entropy class : 0.8841151220488478
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Race - Ethnicity= 0.0022015693411996384
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 656
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 657
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 658
# root: {'name': 'Convicting Offense Type', 'value': 'Other'}
# Entropy class : 0.9899927915575188
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Race - Ethnicity= 0.00014213622792913494
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 659
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 660
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 661
# root: {'name': 'Convicting Offense Type', 'value': 'Violent'}
# Entropy class : 0.8366407419411673
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Race - Ethnicity= 0.08696657541873176
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 662
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 663
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 664
# root: {'name': 'Main Supervising District', 'value': '5JD'}
# Entropy class : 0.9965398868023259
# Info_gain of Race - Ethnicity= 0.0013670970459169762
# Info_gain of Convicting Offense Subtype= 0.002792124150474029
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Classification= 7.962844221787169e-05
# Info_gain of Convicting Offense Type= 0.008588282889106624
# Best variable: Convicting Offense Type
# --------------------------------------------------
# iteration : 665
# root: {'name': 'Convicting Offense Type', 'value': 'Drug'}
# Entropy class : 0.9970590569034107
# Info_gain of Race - Ethnicity= 0.001630438285772473
# Info_gain of Convicting Offense Subtype= 0.005208548268261004
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Classification= 0.002040246182977823
# Best variable: Convicting Offense Subtype
# --------------------------------------------------
# iteration : 666
# root: {'name': 'Convicting Offense Subtype', 'value': 'Other'}
# Entropy class : 0.9544340029249649
# Info_gain of Race - Ethnicity= 0.09235938389499476
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Classification= 0.016712904321817157
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 667
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# all the classes are the same, leaf = 1
# --------------------------------------------------
# iteration : 668
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# Entropy class : 0.9852281360342516
# Info_gain of Convicting Offense Classification= 0.03914867190307081
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Convicting Offense Classification
# --------------------------------------------------
# iteration : 669
# root: {'name': 'Convicting Offense Classification', 'value': 'D Felony'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 670
# root: {'name': 'Convicting Offense Classification', 'value': 'Other Felony'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 671
# root: {'name': 'Convicting Offense Subtype', 'value': 'Trafficking'}
# Entropy class : 0.9995256892936493
# Info_gain of Convicting Offense Classification= 0.0015145201869797287
# Info_gain of Race - Ethnicity= 0.00022162019926041943
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Convicting Offense Classification
# --------------------------------------------------
# iteration : 672
# root: {'name': 'Convicting Offense Classification', 'value': 'D Felony'}
# Entropy class : 0.9709505944546686
# Info_gain of Race - Ethnicity= 0.3219280948873623
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 673
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# all the classes are the same, leaf = 0
# --------------------------------------------------
# iteration : 674
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 675
# root: {'name': 'Convicting Offense Classification', 'value': 'Other Felony'}
# Entropy class : 0.9998646331239298
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Race - Ethnicity= 0.0025148432103171414
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 676
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 677
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 678
# root: {'name': 'Convicting Offense Type', 'value': 'Other'}
# Entropy class : 0.9902246902198684
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Race - Ethnicity= 0.008118457575125637
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Classification= 0.004780172526121618
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 679
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# Entropy class : 0.9293636260137187
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Convicting Offense Classification= 0.03540132020509257
# Info_gain of Fiscal Year Released= 0.0
# Best variable: Convicting Offense Classification
# --------------------------------------------------
# iteration : 680
# root: {'name': 'Convicting Offense Classification', 'value': 'D Felony'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 681
# root: {'name': 'Convicting Offense Classification', 'value': 'Other Felony'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 682
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# Entropy class : 0.9974015885677396
# Info_gain of Convicting Offense Classification= 0.0010905162318257666
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Subtype= 0.0
# Best variable: Convicting Offense Classification
# --------------------------------------------------
# iteration : 683
# root: {'name': 'Convicting Offense Classification', 'value': 'D Felony'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 684
# root: {'name': 'Convicting Offense Classification', 'value': 'Other Felony'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 685
# root: {'name': 'Convicting Offense Type', 'value': 'Violent'}
# Entropy class : 0.9568886656798212
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Classification= 0.025131219083578293
# Info_gain of Race - Ethnicity= 6.455942045502372e-05
# Best variable: Convicting Offense Classification
# --------------------------------------------------
# iteration : 686
# root: {'name': 'Convicting Offense Classification', 'value': 'D Felony'}
# Entropy class : 0.8112781244591328
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Race - Ethnicity= 0.027118996607711
# Info_gain of Convicting Offense Subtype= 0.0
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 687
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 688
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 689
# root: {'name': 'Convicting Offense Classification', 'value': 'Other Felony'}
# Entropy class : 0.9895875212220557
# Info_gain of Fiscal Year Released= 0.0
# Info_gain of Convicting Offense Subtype= 0.0
# Info_gain of Race - Ethnicity= 0.00014888004894531015
# Best variable: Race - Ethnicity
# --------------------------------------------------
# iteration : 690
# root: {'name': 'Race - Ethnicity', 'value': 'Black'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------
# iteration : 691
# root: {'name': 'Race - Ethnicity', 'value': 'White'}
# all the rows have the same value: leaf = 0
# --------------------------------------------------

# %%
def classify_tree(Tree , x):
    nid = Tree.root
    if Tree[nid].is_leaf():
        return Tree[nid].data.value
    else:
        for h in Tree.is_branch(nid):
            if x[Tree[nid].data.value][0] == Tree[h].data.parent_value:
                return classify_tree(Tree.subtree(h), x.drop(Tree[Tree[nid].data.value, 1]))

# %%
x = pd.DataFrame({"Fiscal Year Released":["2010"],"Recidivism Reporting Year":["2013"], 
                  "Age At Release": ["<45"], "Convicting Offense Classification":["D Felony"],"Convicting Offense Type":["Violent"],
                  "Convicting Offense Subtype":["Other"],"Main Supervising District":["3JD"],"Release Type":["Parole"],
                  "Part of Target Population":["Yes"],"Recidivism - Return to Prison numeric":["Yes"]})

label = classify_tree(T, x)

# %%
print(label)

# %% [markdown]
# i surrendered here unfortunatly i didnt have enough time to debug this

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
X = data.drop(columns=['Recidivism - Return to Prison numeric'])
y = data['Recidivism - Return to Prison numeric']

# %%
X_encoded = pd.get_dummies(X)


X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# %%
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred = clf.predict(X_test)

# %%
correct_predictions = sum(y_pred == y_test)  
total_predictions = len(y_test)

# %%
accuracy = correct_predictions / total_predictions  

print(f"Accuracy of the Decision Tree model: {accuracy * 100:.2f}%")
# Out:
# Accuracy of the Decision Tree model: 71.77%

# %% [markdown]
# ## 2)

# %%
TP = sum((y_pred == 1) & (y_test == 1))  # True Positives
TN = sum((y_pred == 0) & (y_test == 0))  # True Negatives
FP = sum((y_pred == 1) & (y_test == 0))  # False Positives
FN = sum((y_pred == 0) & (y_test == 1))  # False Negatives


confusion_matrix = pd.DataFrame({
    "Predicted 0": [TN, FP],
    "Predicted 1": [FN, TP]
}, index=["Actual 0", "Actual 1"])


print("\nConfusion Matrix:")
print(confusion_matrix)
# Out:
# Confusion Matrix:
#           Predicted 0  Predicted 1
# Actual 0         1005          519
# Actual 1          352         1209

# %% [markdown]
# ## 3)

# %% [markdown]
# we can add even more stopping conditions in the tree construction which will lower the iteration number but not significatly in my case .

# %% [markdown]
# we can add another base condition : for example :

# %%
    elif len(data) < min_samples_split:
        T = Tree()
        prediction = data[class_name].mode()[0]
        T.create_node(str(prediction) + "| {}= {}".format(_root["name"], _root["value"]), str(id))
        out_str += "Too few samples, stopping. Leaf = {}\n".format(prediction)
        out_str += "-" * 50 + "\n"
        return T, id + 1, out_str
# Out:
#   Cell In[258], line 1
#     Base case 3: If there are too few samples to split (less than min_samples_split), the function stops splitting and creates a leaf node with the most frequent class. It logs this condition and returns the tree with the leaf.
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# we pass the min_samples to the main function for example 5 . and add code snipit above below the last condition . the iterations will go from 691 to 614 in that case .

# %% [markdown]
# the condition is stoping the tree construnction when we have less than min_samples_split = 5 (for example)
